# %%
# This code block stores file paths to variables to make the code neat
# The stored variables are called in the read_excel function and stored as dataframes

import pandas as pd
import numpy as np

# Store excel file locations to variables (change it as per your path to file)
file_2012=r"C:\Users\warra\Desktop\Freelance\data\data\FemaleMerge\1. Merging by Parts\17. Section 5 Participation in social safety net, perception & Utiization of NGO Services\2012_s7.csv"
file_2013=r"C:\Users\warra\Desktop\Freelance\data\data\FemaleMerge\1. Merging by Parts\17. Section 5 Participation in social safety net, perception & Utiization of NGO Services\2013_s7.csv"
file_2014=r"C:\Users\warra\Desktop\Freelance\data\data\FemaleMerge\1. Merging by Parts\17. Section 5 Participation in social safety net, perception & Utiization of NGO Services\2014_s5p1_f.csv"

# Read excel files
df_2012 = pd.read_csv(file_2012)
df_2013 = pd.read_csv(file_2013, low_memory=False)
df_2014 = pd.read_csv(file_2014)

# %%
'''
This code block will be used to standardize column names across the years to avoid discrepancies during the merging process.
For example in the roaster data for 2013 rq21 and rq23 are not the same as rq21 and rq23 in 2014 data, but they have the same variable names. Hence, we decide to rename such columns beforehand
We will add the updated name to the mapping dictionaries instead of the original names.

'''

# Rename columns in df_2012
df_2012.rename(columns={
    'S7P4Q1': 's5p1_qa',
    'program': 's5p1_q1',
    'pid': 'r_pid',
    'S7P4Q3': 'Cash_Rs',
    'S7P4Q4': 'Wheat_KG',
    'S7P4Q5': 'OF_Rs',
    'S7P4Q6': 'InKind_Rs',
    'PROVINCE_ID': 'P_ID',
    'DISTRICT_ID': 'D_ID',
    'TEHSIL_ID': 'T_ID',
    'UC_ID': 'UC_ID',
    'MAUZA_ID': 'M_ID',
    'NGO_id': 'NGO_Code',
    'S7P2Q1': 'NGO_Aware',
    'S7P2Q2': 'NGO_ActiveT'
}, inplace=True)

# Rename columns in df_2013
df_2013.rename(columns={
    's7p1_q4': 's5p1_qa',
    's7p1_sr': 's5p1_q1',
    's7p1_q11': 's5p1_q11',
    's7p1_program': 'Prgm_Name',
    's7p1_q2': 'Prgm_Aware',
    's7p1_q3': 'Prgm_TActive',
    's7p1_q6': 'Spend_Decision',
    's7p1_q7': 'Cash_Rs',
    's7p1_q8': 'Wheat_KG',
    's7p1_q9': 'OF_Rs',
    's7p1_q10': 'InKind_Rs',
    's7p2_sr': 'NGO_Code',
    's7p2_ngo_name': 'NGO_Name',
    's7p2_q2': 'NGO_Aware',
    's7p2_q3': 'NGO_ActiveT',
    's7p2_q4': 'NGO_Percep',
    's7p2_q5': 'NGO_Train',
    's7p2_q6': 'NGO_RPGoC_12m',
    's7p2_q7': 'NGO_Cash',
    's7p2_q8': 'NGO_Wheat',
    's7p2_q9': 'NGO_OF',
    's7p2_q10': 'NGO_InKind',
    's7p2_q11': 'NGO_GPGoC_12m',
    's7p2_q12': 'NGO_CashG',
    's7p2_q13': 'NGO_WheatG',
    's7p2_q14': 'NGO_OFG',
    's7p2_q15': 'NGO_InKindG',
    's7p2_q16': 'NGO_Mem'
}, inplace=True)

# df_2014 doesn't need renaming as it is the reference

# %%
# Updated mappings

mapping_2012 = [
    'hid', 'round', 's5p1_qa', 's5p1_q1', 'r_pid', None, None, None, None, None,
    None, None, None, None, None, None, None, None, None, 'Cash_Rs', 'Wheat_KG', 
    'OF_Rs', 'InKind_Rs', 'P_ID', 'D_ID', 'T_ID', 'UC_ID', 'M_ID',
    'NGO_Code', None, 'NGO_Aware', 'NGO_ActiveT', None, None, None, None,
    None, None, None, None, None, None, None, None, None
]

mapping_2013 = [
    'hid', 'round', 's5p1_qa', 's5p1_q1', 'r_pid', None, None, None, None, None, None, None, None, None,
    's5p1_q11', 'Prgm_Name', 'Prgm_Aware', 'Prgm_TActive', 'Spend_Decision', 'Cash_Rs',
    'Wheat_KG', 'OF_Rs', 'InKind_Rs', None, None, None, None, None, 'NGO_Code', 'NGO_Name',
    'NGO_Aware', 'NGO_ActiveT', 'NGO_Percep', 'NGO_Train', 'NGO_RPGoC_12m', 'NGO_Cash', 'NGO_Wheat',
    'NGO_OF', 'NGO_InKind', 'NGO_GPGoC_12m', 'NGO_CashG', 'NGO_WheatG', 'NGO_OFG', 'NGO_InKindG', 'NGO_Mem'
]

mapping_2014 = [
    'hid', 'round', 's5p1_qa', 's5p1_q1', 'r_pid', 's5p1_q3_mm', 's5p1_q3_yyyy',
    's5p1_q4', 's5p1_q5', 's5p1_q6', 's5p1_q7', 's5p1_q8', 's5p1_q9', 's5p1_q10',
    's5p1_q11', None, None, None, None, None, None, None, None, None, None, None,
    None, None, None, None, None, None, None, None, None, None, None, None, None,
    None, None, None, None,  None, None
]

# %%
# Create a list of all possible columns in the correct order
all_columns = []

for col in mapping_2012:
    if col and col not in all_columns:
        all_columns.append(col)   
for col in mapping_2013:
    if col and col not in all_columns:
        all_columns.append(col)
for col in mapping_2014:
    if col and col not in all_columns:
        all_columns.append(col)

# %%
def standardize_and_merge(dfs, mappings, all_columns):
    merged_data = {col: [] for col in all_columns}

    for df, mapping in zip(dfs, mappings):
        print(f"Processing DataFrame with columns: {df.columns.tolist()}")
        for i, col in enumerate(mapping):
            if col:
                ref_col = col.strip()  # Remove leading/trailing whitespace
                if ref_col not in merged_data:
                    merged_data[ref_col] = []
                if ref_col in df.columns:
                    print(f"Appending data for column {ref_col}")
                    if isinstance(df[ref_col], pd.Series):
                        merged_data[ref_col].extend(df[ref_col].tolist())
                    elif isinstance(df[ref_col], pd.DataFrame):
                        print(f"Column {ref_col} is duplicated in DataFrame. Appending data for each duplicate.")
                        for _, series in df[ref_col].items():
                            merged_data[ref_col].extend(series.tolist())
                else:
                    print(f"Column {ref_col} not found in DataFrame. Adding NaNs.")
                    merged_data[ref_col].extend([np.nan] * len(df))
    
    max_len = max(len(v) for v in merged_data.values())
    for key in merged_data:
        col_len = len(merged_data[key])
        if col_len < max_len:
            merged_data[key].extend([np.nan] * (max_len - col_len))

    merged_df = pd.DataFrame.from_dict(merged_data)
    return merged_df

# %%
# Usage with dataframes and mappings
dfs = [df_2012, df_2013, df_2014]
mappings = [mapping_2012, mapping_2013, mapping_2014]

merged_df = standardize_and_merge(dfs, mappings, all_columns)
# Out:
# Processing DataFrame with columns: ['Unnamed: 0', 'hid', 'round', 's5p1_q1', 's5p1_qa', 'r_pid', 'Cash_Rs', 'Wheat_KG', 'OF_Rs', 'InKind_Rs', 'P_ID', 'D_ID', 'T_ID', 'UC_ID', 'M_ID', 'NGO_Code', 'NGO_Aware', 'NGO_ActiveT', 'S7P2Q3', 'S7P2Q4', 'S7P2Q5', 'S7P2Q6']
# Appending data for column hid
# Appending data for column round
# Appending data for column s5p1_qa
# Appending data for column s5p1_q1
# Appending data for column r_pid
# Appending data for column Cash_Rs
# Appending data for column Wheat_KG
# Appending data for column OF_Rs
# Appending data for column InKind_Rs
# Appending data for column P_ID
# Appending data for column D_ID
# Appending data for column T_ID
# Appending data for column UC_ID
# Appending data for column M_ID
# Appending data for column NGO_Code
# Appending data for column NGO_Aware
# Appending data for column NGO_ActiveT
# Processing DataFrame with columns: ['Unnamed: 0', 'hid', 'round', 's5p1_q1', 'Prgm_Name', 'Prgm_Aware', 'Prgm_TActive', 's5p1_qa', 'r_pid', 'Spend_Decision', 'Cash_Rs', 'Wheat_KG', 'OF_Rs', 'InKind_Rs', 's5p1_q11', 'NGO_Code', 'NGO_Name', 'NGO_Aware', 'NGO_ActiveT', 'NGO_Percep', 'NGO_Train', 'NGO_RPGoC_12m', 'NGO_Cash', 'NGO_Wheat', 'NGO_OF', 'NGO_InKind', 'NGO_GPGoC_12m', 'NGO_CashG', 'NGO_WheatG', 'NGO_OFG', 'NGO_InKindG', 'NGO_Mem']
# Appending data for column hid
# Appending data for column round
# Appending data for column s5p1_qa
# Appending data for column s5p1_q1
# Appending data for column r_pid
# Appending data for column s5p1_q11
# Appending data for column Prgm_Name
# Appending data for column Prgm_Aware
# Appending data for column Prgm_TActive
# Appending data for column Spend_Decision
# Appending data for column Cash_Rs
# Appending data for column Wheat_KG
# Appending data for column OF_Rs
# Appending data for column InKind_Rs
# Appending data for column NGO_Code
# Appending data for column NGO_Name
# Appending data for column NGO_Aware
# Appending data for column NGO_ActiveT
# Appending data for column NGO_Percep
# Appending data for column NGO_Train
# Appending data for column NGO_RPGoC_12m
# Appending data for column NGO_Cash
# Appending data for column NGO_Wheat
# Appending data for column NGO_OF
# Appending data for column NGO_InKind
# Appending data for column NGO_GPGoC_12m
# Appending data for column NGO_CashG
# Appending data for column NGO_WheatG
# Appending data for column NGO_OFG
# Appending data for column NGO_InKindG
# Appending data for column NGO_Mem
# Processing DataFrame with columns: ['Unnamed: 0', 'hid', 'round', 's5p1_qa', 's5p1_q1', 'r_pid', 's5p1_q3_mm', 's5p1_q3_yyyy', 's5p1_q4', 's5p1_q5', 's5p1_q6', 's5p1_q7', 's5p1_q8', 's5p1_q9', 's5p1_q10', 's5p1_q11']
# Appending data for column hid
# Appending data for column round
# Appending data for column s5p1_qa
# Appending data for column s5p1_q1
# Appending data for column r_pid
# Appending data for column s5p1_q3_mm
# Appending data for column s5p1_q3_yyyy
# Appending data for column s5p1_q4
# Appending data for column s5p1_q5
# Appending data for column s5p1_q6
# Appending data for column s5p1_q7
# Appending data for column s5p1_q8
# Appending data for column s5p1_q9
# Appending data for column s5p1_q10
# Appending data for column s5p1_q11

# %%
# Rename columns for the merged file (if needed)
rename_mapping = {
   'hid': 'HID',
    'round': 'Survey_Round',
    's5p1_qa': 'HHB_12m',
    's5p1_q1': 'Prgm_Code',
    'r_pid': 'PID',
    's5p1_q3_mm': 'HHBStart_m',
    's5p1_q3_yyyy': 'HHBStart_y',
    's5p1_q4': 'HHB_Freq',
    's5p1_q5': 'Assist_Type',
    's5p1_q6': 'B_AmtRET',
    's5p1_q7': 'Cash_AmtR1y',
    's5p1_q8': 'Cash_MaxSpend',
    's5p1_q9': 'IKI_TVal1y',
    's5p1_q10': 'Main_Use',
    's5p1_q11': 'Prgm_Percep'
}

merged_df.rename(columns=rename_mapping, inplace=True)
'''
# Drop redundant columns
merged_df.drop(merged_df.columns[merged_df.columns.str.contains('Unnamed', case=True)], axis=1, inplace=True)
merged_df.drop(merged_df.columns[merged_df.columns.str.contains(' ', case=False)], axis=1, inplace=True)
'''
# Save the merged dataframe to a CSV file
merged_df.to_csv('1. merged_Social Safety Net Programs .csv', index=False)
