# %%
# This code block stores file paths to variables to make the code neat
# The stored variables are called in the read_excel function and stored as dataframes

import pandas as pd
import numpy as np

# Store excel file locations to variables (change it as per your path to file)
file_2012=r"C:\Users\warra\Desktop\Freelance\data\data\FemaleMerge\1. Merging by Parts\32. Section 8 Part 3 Health and Nutrition Immunization and Health Status of Young Children\Recent illness of child\2012_s6p4_f_RIC.csv"
file_2013=r"C:\Users\warra\Desktop\Freelance\data\data\FemaleMerge\1. Merging by Parts\32. Section 8 Part 3 Health and Nutrition Immunization and Health Status of Young Children\Recent illness of child\2013_s4p3_f_RIC.csv"
file_2014=r"C:\Users\warra\Desktop\Freelance\data\data\FemaleMerge\1. Merging by Parts\32. Section 8 Part 3 Health and Nutrition Immunization and Health Status of Young Children\Recent illness of child\2014_s8p4_f_RIC.csv"

# Read excel files
df_2012 = pd.read_csv(file_2012)
df_2013 = pd.read_csv(file_2013)
df_2014 = pd.read_csv(file_2014)

# %%
'''
This code block will be used to standardize column names across the years to avoid discrepancies during the merging process.
For example in the roaster data for 2013 rq21 and rq23 are not the same as rq21 and rq23 in 2014 data, but they have the same variable names. Hence, we decide to rename such columns beforehand
We will add the updated name to the mapping dictionaries instead of the original names.

'''

# Rename columns in df_2012
df_2012.rename(columns={
    'pid': 'r_pid',
    'S6P4Q21': 's8p4_q22',
    'S6P4Q22': 's8p4_q23',
    'S6P4Q23': 's8p4_q24',
    'S6P4Q25': 's8p4_q25',
    'S6P4Q26': 's8p4_q26',
    'S6P4Q27': 's8p4_q27',
    'S6P4Q33': 's8p4_q28',
    'S6P4Q34': 's8p4_q29',
    'S6P4Q35': 's8p4_q30',
    'S6P4Q37': 's8p4_q31',
    'S6P4Q38': 's8p4_q32',
    'S6P4Q39': 's8p4_q33',
    'S6P4Q41': 's8p4_q34',
    'S6P4Q42': 's8p4_q35',
    'S6P4Q40': 'RIC_HMORS',
    'S6P4Q24': 'RIC_FeverMedT_Loc2',
    'S6P4Q28': 'RIC_ColdMedT_Loc2',
    'S6P4Q29': 'RIC_FSB_2w',
    'S6P4Q30': 'RIC_AoTFSB',
    'S6P4Q31': 'RIC_FSBMedT_Loc1',
    'S6P4Q32': 'RIC_FSBMedT_Loc2',
    'S6P4Q36': 'RIC_DiarrMedT_Loc2',
    'PROVINCE_ID': 'P_ID',
    'DISTRICT_ID': 'D_ID',
    'TEHSIL_ID': 'T_ID',
    'UC_ID': 'UC_ID',
    'MAUZA_ID': 'M_ID'
}, inplace=True)

# Rename columns in df_2013
df_2013.rename(columns={
    'mother_pid': 's8p4_mother_pid',
    's4p3_q22': 's8p4_q22',
    's4p3_q23': 's8p4_q23',
    's4p3_q24': 's8p4_q24',
    's4p3_q25': 's8p4_q25',
    's4p3_q26': 's8p4_q26',
    's4p3_q27': 's8p4_q27',
    's4p3_q28': 's8p4_q28',
    's4p3_q29': 's8p4_q29',
    's4p3_q30': 's8p4_q30',
    's4p3_q31': 's8p4_q31',
    's4p3_q32': 's8p4_q32',
    's4p3_q33': 's8p4_q33',
    's4p3_q35': 's8p4_q34',
    's4p3_q36': 's8p4_q35',
    's4p3_q34': 'RIC_HMORS'
}, inplace=True)

# df_2014 doesn't need renaming as it is the reference

# %%
# Updated mappings

mapping_2012 = [
    'hid', 'round', 'r_pid', None, 's8p4_q22', 's8p4_q23', 's8p4_q24', 's8p4_q25',
    's8p4_q26', 's8p4_q27', 's8p4_q28', 's8p4_q29', 's8p4_q30', 's8p4_q31',
    's8p4_q32', 's8p4_q33', 's8p4_q34', 's8p4_q35', 'RIC_HMORS', 'RIC_FeverMedT_Loc2',
    'RIC_ColdMedT_Loc2', 'RIC_FSB_2w', 'RIC_AoTFSB', 'RIC_FSBMedT_Loc1',
    'RIC_FSBMedT_Loc2', 'RIC_DiarrMedT_Loc2', 'P_ID', 'D_ID', 'T_ID', 'UC_ID', 'M_ID'
]

mapping_2013 = [
    'hid', 'round', 'r_pid', 's8p4_mother_pid', 's8p4_q22', 's8p4_q23', 's8p4_q24',
    's8p4_q25', 's8p4_q26', 's8p4_q27', 's8p4_q28', 's8p4_q29', 's8p4_q30', 's8p4_q31',
    's8p4_q32', 's8p4_q33', 's8p4_q34', 's8p4_q35', 'RIC_HMORS', None, None, None, None,
    None, None, None, None, None, None, None, None
]

mapping_2014 = [
    'hid', 'round', 'r_pid', 's8p4_mother_pid', 's8p4_q22', 's8p4_q23', 's8p4_q24', 's8p4_q25',
    's8p4_q26', 's8p4_q27', 's8p4_q28', 's8p4_q29', 's8p4_q30', 's8p4_q31', 's8p4_q32', 's8p4_q33',
    's8p4_q34', 's8p4_q35', None, None, None, None, None, None, None, None, None, None, None, None, None
]

# %%
# Create a list of all possible columns in the correct order
all_columns = []

for col in mapping_2012:
    if col and col not in all_columns:
        all_columns.append(col)   
for col in mapping_2013:
    if col and col not in all_columns:
        all_columns.append(col)
for col in mapping_2014:
    if col and col not in all_columns:
        all_columns.append(col)

# %%
def standardize_and_merge(dfs, mappings, all_columns):
    merged_data = {col: [] for col in all_columns}

    for df, mapping in zip(dfs, mappings):
        print(f"Processing DataFrame with columns: {df.columns.tolist()}")
        for i, col in enumerate(mapping):
            if col:
                ref_col = col.strip()  # Remove leading/trailing whitespace
                if ref_col not in merged_data:
                    merged_data[ref_col] = []
                if ref_col in df.columns:
                    print(f"Appending data for column {ref_col}")
                    if isinstance(df[ref_col], pd.Series):
                        merged_data[ref_col].extend(df[ref_col].tolist())
                    elif isinstance(df[ref_col], pd.DataFrame):
                        print(f"Column {ref_col} is duplicated in DataFrame. Appending data for each duplicate.")
                        for _, series in df[ref_col].items():
                            merged_data[ref_col].extend(series.tolist())
                else:
                    print(f"Column {ref_col} not found in DataFrame. Adding NaNs.")
                    merged_data[ref_col].extend([np.nan] * len(df))
    
    max_len = max(len(v) for v in merged_data.values())
    for key in merged_data:
        col_len = len(merged_data[key])
        if col_len < max_len:
            merged_data[key].extend([np.nan] * (max_len - col_len))

    merged_df = pd.DataFrame.from_dict(merged_data)
    return merged_df

# %%
# Usage with dataframes and mappings
dfs = [df_2012, df_2013, df_2014]
mappings = [mapping_2012, mapping_2013, mapping_2014]

merged_df = standardize_and_merge(dfs, mappings, all_columns)
# Out:
# Processing DataFrame with columns: ['Unnamed: 0.1', 'Unnamed: 0', 'hid', 'round', 'r_pid', 's8p4_q22', 's8p4_q23', 's8p4_q24', 'RIC_FeverMedT_Loc2', 's8p4_q25', 's8p4_q26', 's8p4_q27', 'RIC_ColdMedT_Loc2', 'RIC_FSB_2w', 'RIC_AoTFSB', 'RIC_FSBMedT_Loc1', 'RIC_FSBMedT_Loc2', 's8p4_q28', 's8p4_q29', 's8p4_q30', 'RIC_DiarrMedT_Loc2', 's8p4_q31', 's8p4_q32', 's8p4_q33', 'RIC_HMORS', 's8p4_q34', 's8p4_q35', 'P_ID', 'D_ID', 'T_ID', 'UC_ID', 'M_ID']
# Appending data for column hid
# Appending data for column round
# Appending data for column r_pid
# Appending data for column s8p4_q22
# Appending data for column s8p4_q23
# Appending data for column s8p4_q24
# Appending data for column s8p4_q25
# Appending data for column s8p4_q26
# Appending data for column s8p4_q27
# Appending data for column s8p4_q28
# Appending data for column s8p4_q29
# Appending data for column s8p4_q30
# Appending data for column s8p4_q31
# Appending data for column s8p4_q32
# Appending data for column s8p4_q33
# Appending data for column s8p4_q34
# Appending data for column s8p4_q35
# Appending data for column RIC_HMORS
# Appending data for column RIC_FeverMedT_Loc2
# Appending data for column RIC_ColdMedT_Loc2
# Appending data for column RIC_FSB_2w
# Appending data for column RIC_AoTFSB
# Appending data for column RIC_FSBMedT_Loc1
# Appending data for column RIC_FSBMedT_Loc2
# Appending data for column RIC_DiarrMedT_Loc2
# Appending data for column P_ID
# Appending data for column D_ID
# Appending data for column T_ID
# Appending data for column UC_ID
# Appending data for column M_ID
# Processing DataFrame with columns: ['Unnamed: 0', 'hid', 'round', 'r_pid', 's8p4_mother_pid', 's8p4_q22', 's8p4_q23', 's8p4_q24', 's8p4_q25', 's8p4_q26', 's8p4_q27', 's8p4_q28', 's8p4_q29', 's8p4_q30', 's8p4_q31', 's8p4_q32', 's8p4_q33', 'RIC_HMORS', 's8p4_q34', 's8p4_q35']
# Appending data for column hid
# Appending data for column round
# Appending data for column r_pid
# Appending data for column s8p4_mother_pid
# Appending data for column s8p4_q22
# Appending data for column s8p4_q23
# Appending data for column s8p4_q24
# Appending data for column s8p4_q25
# Appending data for column s8p4_q26
# Appending data for column s8p4_q27
# Appending data for column s8p4_q28
# Appending data for column s8p4_q29
# Appending data for column s8p4_q30
# Appending data for column s8p4_q31
# Appending data for column s8p4_q32
# Appending data for column s8p4_q33
# Appending data for column s8p4_q34
# Appending data for column s8p4_q35
# Appending data for column RIC_HMORS
# Processing DataFrame with columns: ['Unnamed: 0', 'hid', 'round', 'r_pid', 's8p4_mother_pid', 's8p4_q22', 's8p4_q23', 's8p4_q24', 's8p4_q25', 's8p4_q26', 's8p4_q27', 's8p4_q28', 's8p4_q29', 's8p4_q30', 's8p4_q31', 's8p4_q32', 's8p4_q33', 's8p4_q34', 's8p4_q35']
# Appending data for column hid
# Appending data for column round
# Appending data for column r_pid
# Appending data for column s8p4_mother_pid
# Appending data for column s8p4_q22
# Appending data for column s8p4_q23
# Appending data for column s8p4_q24
# Appending data for column s8p4_q25
# Appending data for column s8p4_q26
# Appending data for column s8p4_q27
# Appending data for column s8p4_q28
# Appending data for column s8p4_q29
# Appending data for column s8p4_q30
# Appending data for column s8p4_q31
# Appending data for column s8p4_q32
# Appending data for column s8p4_q33
# Appending data for column s8p4_q34
# Appending data for column s8p4_q35

# %%
# Rename columns for the merged file (if needed)
rename_mapping = {
     'hid': 'HID',
    'round': 'Survey_Round',
    'r_pid': 'PID',
    's8p4_mother_pid': 'PID_Mom',
    's8p4_q22': 'RIC_Fever_2w',
    's8p4_q23': 'RIC_AoTFever',
    's8p4_q24': 'RIC_FeverMedT_Loc1',
    's8p4_q25': 'RIC_Cold_2w',
    's8p4_q26': 'RIC_AoTCold',
    's8p4_q27': 'RIC_ColdMedT_Loc1',
    's8p4_q28': 'RIC_Diarr_2w',
    's8p4_q29': 'RIC_AoTDiarr',
    's8p4_q30': 'RIC_DiarrMedT_Loc1',
    's8p4_q31': 'RIC_Diarr_ORS',
    's8p4_q32': 'RIC_Diarr_ZnTab',
    's8p4_q33': 'RIC_Diarr_AntiBiotics',
    's8p4_q34': 'RIC_Diarr_TraMed',
    's8p4_q35': 'RIC_Diarr_Other'
}

merged_df.rename(columns=rename_mapping, inplace=True)
'''
# Drop redundant columns
merged_df.drop(merged_df.columns[merged_df.columns.str.contains('Unnamed', case=True)], axis=1, inplace=True)
merged_df.drop(merged_df.columns[merged_df.columns.str.contains(' ', case=False)], axis=1, inplace=True)
'''
# Save the merged dataframe to a CSV file
merged_df.to_csv('5. merged_HnN_Immune & Health status of childern Part c.csv', index=False)
