# %%
# This code block stores file paths to variables to make the code neat
# The stored variables are called in the read_excel function and stored as dataframes

import pandas as pd
import numpy as np

# Store excel file locations to variables (change it as per your path to file)
file_2012=r"C:\Users\warra\Desktop\Freelance\data\data\FemaleMerge\1. Merging by Parts\2. Section 1 Part 1 Education - Schooling\2012_s1p1-p3_f.xlsx"
file_2013=r"C:\Users\warra\Desktop\Freelance\data\data\FemaleMerge\1. Merging by Parts\2. Section 1 Part 1 Education - Schooling\2013_s1p1-p3.csv"
file_2014=r"C:\Users\warra\Desktop\Freelance\data\data\FemaleMerge\1. Merging by Parts\2. Section 1 Part 1 Education - Schooling\2014_s1p1-p3.csv"

# Read excel files
df_2012 = pd.read_excel(file_2012)
df_2013 = pd.read_csv(file_2013)
df_2014 = pd.read_csv(file_2014)

# %%
'''
This code block will be used to standardize column names across the years to avoid discrepancies during the merging process.
For example in the roaster data for 2013 rq21 and rq23 are not the same as rq21 and rq23 in 2014 data, but they have the same variable names. Hence, we decide to rename such columns beforehand
We will add the updated name to the mapping dictionaries instead of the original names.

'''

# Rename columns in df_2012
df_2012.rename(columns={
    'pid': 'r_pid',
    'S1Q3': 's1p1_q2',
    'S1Q4': 's1p1_q3',
    'S1Q5': 's1p1_q4',
    'S1Q6': 's1p1_q6',
    'S1Q7': 's1p1_q8',
    'S1Q8': 's1p1_q10',
    'S1Q9': 's1p1_q11',
    'S1Q10': 's1p1_q12',
    'S1Q11': 's1p1_q13',
    'S1Q12': 's1p1_q14',
    'S1Q14_12': 's1p1_q15',
    'S1Q15': 's1p1_q16',
    'S1P2Q2_CODE': 's1p2_q2_code',
    'S1P2Q3': 's1p2_q3',
    'S1P2Q4': 's1p2_q4',
    'S1P2Q5': 's1p2_q5',
    'S1P2Q6_KM': 's1p2_q6',
    'S1P2Q7': 's1p2_q11',
    'S1P2Q8': 's1p2_q12',
    'S1P2Q9': 's1p2_q13',
    'S1P2Q10': 's1p2_q14',
    'S1P2Q11': 's1p2_q15',
    'S1P2Q12': 's1p2_q16',
    'age': 'R_Age',
    'q2': '2012_q2',
    'S1Q13': 'Sch_NotAttend_FoND',
    'S1Q14_24': 'Sch_DayMissed_24m',
    'S1P2Q6_MIN': 'HtSch_DistMins',
    'S1P3AQ2': 'PSchGS',
    'S1P3AQ3A': 'PSchGS_Concern_StTA',
    'S1P3AQ3B': 'PSchGS_Concern_TMPTH',
    'S1P3AQ4': 'PSchGOS_WalkDist',
    'S1P3AQ5': 'PSchGS_NHHSZ',
    'S1P3AQ6A': 'PSchGOS_Concern_StTA',
    'S1P3AQ6B': 'PSchGOS_Concern_TMPTH',
    'S1P3AQ7': 'MSchGS_6t8y',
    'S1P3AQ8A': 'MSchGS_Concern_TMPTH',
    'S1P3AQ8B': 'MSchGS_Concern_StTA',
    'S1P3AQ9': 'MSchGOS_WalkDist',
    'S1P3AQ10': 'MSchGS_NHHSZ',
    'S1P3AQ11A': 'MSchGOS_Concern_TMPTH',
    'S1P3AQ11B': 'MSchGOS_Concern_StTA',
    'S1P3BQ2': 'MSch',
    'S1P3BQ3A': 'MSch_Concern_TMPTH',
    'S1P3BQ3B': 'MSch_Concern_StTA',
    'S1P3BQ4': 'MSch_WalkDist',
    'S1P3BQ5': 'MSch_NearHHSzaat',
    'S1P3BQ6A': 'MSch_NearConcern_TMPTH',
    'S1P3BQ6B': 'MSch_NearConcern_StTA',
    'S1P3BQ7': 'MSch_Prgm',
    'S1P3BQ8': 'MSch_PrgmAttempt',
    'PROVINCE_ID': 'P_ID',
    'DISTRICT_ID': 'D_ID',
    'TEHSIL_ID': 'T_ID',
    'UC_ID': 'UC_ID',
    'MAUZA_ID': 'M_ID'
}, inplace=True)

# Rename columns in df_2013
df_2013.rename(columns={
    's1p1_q6': 's1p1_q5',
    's1p1_q9': 's1p1_q6',
    's1p1_q10': 's1p1_q7',
    's1p1_q11': 's1p1_q8',
    's1p1_q12': 's1p1_q10',
    's1p1_q13': 's1p1_q11',
    's1p1_q14': 's1p1_q12',
    's1p1_q15': 's1p1_q13',
    's1p1_q16': 's1p1_q14',
    's1p1_q17': 's1p1_q15',
    's1p1_q18': 's1p1_q16', 
    's1p1_q5': 'R_PhyDis',
    's1p1_q7': 'R_HW',
    's1p1_q8': 'ImpGoodEdu',
    's1p3_sr': '2013_s1p3_sr',
    's1p3_school_type': 'Sch_Level',
    's1p3_q1_code': 'Sch_NearH',
    's1p3_q2_code': 'Sch_Name2n3H',
    's1p3_q3': 'HtSch_MinsWalking',
    's1p3_q4': 'Sch_LocHH',
    's1p3_q5': 'Sch_Types',
    's1p3_q6': 'SchQuality_OverAll',
    's1p3_q7': 'SchQuality_Teach',
    's1p3_q8': 'SchQuality_InfraStr'
}, inplace=True)

# df_2014 doesn't need renaming as it is the reference

# %%
# Updated mappings

mapping_2012 = [
     'hid', 'round', None, 'r_pid', 's1p1_q2', 's1p1_q3', 's1p1_q4',
    None, 's1p1_q6', None, 's1p1_q8', None, 's1p1_q10', 's1p1_q11',
    's1p1_q12', 's1p1_q14', 's1p1_q15', None, 's1p2_q2_code',
    's1p2_q3', 's1p2_q4', 's1p2_q6', 's1p2_q5', None, None, None,
    None, 's1p2_q11', 's1p2_q12', 's1p2_q13', 's1p2_q14', 's1p2_q15',
    's1p2_q16', None, None, None, None, None, None, None, None, None,
    None, None, None, None, None, None, None, None, None, None, None,
    None, None, None, None, None, None, None, None, None, None, None,
    None, None, None, None, None, None, 'R_Age',	'2012_q2',	'Sch_NotAttend_FoND',
    'Sch_DayMissed_24m',	'HtSch_DistMins',	'PSchGS',	'PSchGS_Concern_StTA',	'PSchGS_Concern_TMPTH',
    'PSchGOS_WalkDist',	'PSchGS_NHHSZ',	'PSchGOS_Concern_StTA',	'PSchGOS_Concern_TMPTH',	'MSchGS_6t8y',	'MSchGS_Concern_TMPTH',	'MSchGS_Concern_StTA',
    'MSchGOS_WalkDist',	'MSchGS_NHHSZ',	'MSchGOS_Concern_TMPTH',	'MSchGOS_Concern_StTA',	'MSch',	'MSch_Concern_TMPTH',	'MSch_Concern_StTA',
    'MSch_WalkDist',	'MSch_NearHHSzaat',	'MSch_NearConcern_TMPTH',	'MSch_NearConcern_StTA',	'MSch_Prgm',	'MSch_PrgmAttempt',
    'P_ID',	'D_ID',	'T_ID',	'UC_ID',	'M_ID'

]

mapping_2013 = [
    'hid', 'round', None, 'r_pid', 's1p1_q2', 's1p1_q3', 's1p1_q4', 's1p1_q5', 's1p1_q6', 's1p1_q7', 's1p1_q8', 's1p1_q10', None, 
    's1p1_q11', 's1p1_q12', 's1p1_q13', 's1p1_q14', 's1p1_q15', 's1p1_q16', None, 's1p2_q2_code', 's1p2_q3', 
    's1p2_q4', 's1p2_q5', 's1p2_q6', 's1p2_q7', 's1p2_q8', 's1p2_q9', 's1p2_q10', 's1p2_q11', 's1p2_q12', 's1p2_q13', 
    's1p2_q14', 's1p2_q15', 's1p2_q16',  None, None, None, None, None, None, None, None, None, None, None, None, 
    None, None, None, None, None, None, None, None, None, None, 'R_PhyDis', 'R_HW', 'ImpGoodEdu', '2013_s1p3_sr', 'Sch_Level', 
    'Sch_NearH', 'Sch_Name2n3H', 'HtSch_MinsWalking', 'Sch_LocHH', 'Sch_Types', 'SchQuality_OverAll', 'SchQuality_Teach', 
    'SchQuality_InfraStr', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 
    None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None
]

mapping_2014 = [
    'hid', 'round', 's1p1_qa', 'r_pid', 's1p1_q2', 's1p1_q3', 's1p1_q4', 's1p1_q5', 's1p1_q6',
    's1p1_q7', 's1p1_q8', 's1p1_q9', 's1p1_q10', 's1p1_q11', 's1p1_q12', 's1p1_q13', 's1p1_q14',
    's1p1_q15', 's1p1_q16', 's1p2_qa', 's1p2_q2_code', 's1p2_q3', 's1p2_q4', 's1p2_q5', 's1p2_q6',
    's1p2_q7', 's1p2_q8', 's1p2_q9', 's1p2_q10', 's1p2_q11', 's1p2_q12', 's1p2_q13', 's1p2_q14',
    's1p2_q15', 's1p2_q16', 's1p2_q17', 's1p3_q1', 's1p3_q2', 's1p3_q3', 's1p3_q4', 's1p3_q5',
    's1p3_q6a', 's1p3_q6b', 's1p3_q6c', 's1p3_q7a', 's1p3_q7b', 's1p3_q7c', 's1p3_q7d', 's1p3_q7e',
    's1p3_q7f', 's1p3_q8', 's1p3_q9', 's1p3_q10', 's1p3_q11', 's1p3_q12', 's1p3_q13', 's1p3_q14', None, None, None, None, None, None, None, None, None,
    None, None, None, None, None, None, None, None, None, None,
    None, None, None, None, None, None, None, None, None, None,
    None, None, None, None,None, None, None, None, None,
    None, None, None,None, None, None, None, None
]

# %%
# Create a list of all possible columns in the correct order
all_columns = []

for col in mapping_2012:
    if col and col not in all_columns:
        all_columns.append(col)   
for col in mapping_2013:
    if col and col not in all_columns:
        all_columns.append(col)
for col in mapping_2014:
    if col and col not in all_columns:
        all_columns.append(col)

# %%
def standardize_and_merge(dfs, mappings, all_columns):
    merged_data = {col: [] for col in all_columns}

    for df, mapping in zip(dfs, mappings):
        print(f"Processing DataFrame with columns: {df.columns.tolist()}")
        for i, col in enumerate(mapping):
            if col:
                ref_col = col.strip()  # Remove leading/trailing whitespace
                if ref_col not in merged_data:
                    merged_data[ref_col] = []
                if ref_col in df.columns:
                    print(f"Appending data for column {ref_col}")
                    if isinstance(df[ref_col], pd.Series):
                        merged_data[ref_col].extend(df[ref_col].tolist())
                    elif isinstance(df[ref_col], pd.DataFrame):
                        print(f"Column {ref_col} is duplicated in DataFrame. Appending data for each duplicate.")
                        for _, series in df[ref_col].items():
                            merged_data[ref_col].extend(series.tolist())
                else:
                    print(f"Column {ref_col} not found in DataFrame. Adding NaNs.")
                    merged_data[ref_col].extend([np.nan] * len(df))
    
    max_len = max(len(v) for v in merged_data.values())
    for key in merged_data:
        col_len = len(merged_data[key])
        if col_len < max_len:
            merged_data[key].extend([np.nan] * (max_len - col_len))

    merged_df = pd.DataFrame.from_dict(merged_data)
    return merged_df

# %%
# Usage with dataframes and mappings
dfs = [df_2012, df_2013, df_2014]
mappings = [mapping_2012, mapping_2013, mapping_2014]

merged_df = standardize_and_merge(dfs, mappings, all_columns)
# Out:
# Processing DataFrame with columns: ['Unnamed: 0', 'hid', 'round', 'r_pid', 'R_Age', '2012_q2', 's1p1_q2', 's1p1_q3', 's1p1_q4', 's1p1_q6', 's1p1_q8', 's1p1_q10', 's1p1_q11', 's1p1_q12', 's1p1_q13', 's1p1_q14', 'Sch_NotAttend_FoND', 's1p1_q15', 'Sch_DayMissed_24m', 's1p1_q16', 's1p2_q2_code', 's1p2_q3', 's1p2_q4', 's1p2_q5', 's1p2_q6', 'HtSch_DistMins', 's1p2_q11', 's1p2_q12', 's1p2_q13', 's1p2_q14', 's1p2_q15', 's1p2_q16', 'PSchGS', 'PSchGS_Concern_StTA', 'PSchGS_Concern_TMPTH', 'PSchGOS_WalkDist', 'PSchGS_NHHSZ', 'PSchGOS_Concern_StTA', 'PSchGOS_Concern_TMPTH', 'MSchGS_6t8y', 'MSchGS_Concern_TMPTH', 'MSchGS_Concern_StTA', 'MSchGOS_WalkDist', 'MSchGS_NHHSZ', 'MSchGOS_Concern_TMPTH', 'MSchGOS_Concern_StTA', 'MSch', 'MSch_Concern_TMPTH', 'MSch_Concern_StTA', 'MSch_WalkDist', 'MSch_NearHHSzaat', 'MSch_NearConcern_TMPTH', 'MSch_NearConcern_StTA', 'MSch_Prgm', 'MSch_PrgmAttempt', 'P_ID', 'D_ID', 'T_ID', 'UC_ID', 'M_ID']
# Appending data for column hid
# Appending data for column round
# ...

# %%
# Rename columns for the merged file (if needed)
rename_mapping = {
    'hid': 'HID',
    'round': 'Survey_Round',
    's1p1_qa': 'CoF_HH',
    'r_pid': 'PID',
    's1p1_q2': 'Read',
    's1p1_q3': 'Write',
    's1p1_q4': 'AddSub',
    's1p1_q5': 'Intel',
    's1p1_q6': 'Sch_Attend',
    's1p1_q7': 'Res_Not_Attend',
    's1p1_q8': 'Sch_Type',
    's1p1_q9': 'Medium',
    's1p1_q10': 'Sch_AgeStart_y',
    's1p1_q11': 'Sch_StillAttend',
    's1p1_q12': 'Sch_AgeStop_y',
    's1p1_q13': 'Sch_Stop_Res',
    's1p1_q14': 'RepClass',
    's1p1_q15': 'Sch_DayMissed_12m',
    's1p1_q16': 'H_Class',
    's1p2_qa': 'C_HHAttendSch',
    's1p2_q2_code': 'Sch_ID',
    's1p2_q3': 'R_TravelHtSch',
    's1p2_q4': 'HtSch_Time',
    's1p2_q5': 'HtSch_DistKM',
    's1p2_q6': 'HH_TripVal_12m',
    's1p2_q7': 'R_EnrolSch_Res',
    's1p2_q8': 'R_MissSch_4w',
    's1p2_q9': 'R_MissSchRes_4w',
    's1p2_q10': 'R_MissSchDays_4w',
    's1p2_q11': 'HH_SchFee_12m',
    's1p2_q12': 'HH_SchClo_12m',
    's1p2_q13': 'HH_SchStation_12m',
    's1p2_q14': 'R_AttendSchDays_12m',
    's1p2_q15': 'R_FAIKAssist_12m',
    's1p2_q16': 'R_FAIKAssistVal_12m',
    's1p2_q17': 'Teach_SchMissDays_4w',
    's1p3_q1': 'Per_GPSch_MF',
    's1p3_q2': 'Per_GSSch_MF',
    's1p3_q3': 'Per_BPSch_MF',
    's1p3_q4': 'Per_BSSch_MF',
    's1p3_q5': 'Per_Cheat',
    's1p3_q6a': 'Per_Help',
    's1p3_q6b': 'Per_SendBoG',
    's1p3_q6c': 'Per_PracSkills',
    's1p3_q7a': 'Per_SchQuality_Stud',
    's1p3_q7b': 'Per_SchQuality_Teach',
    's1p3_q7c': 'Per_SchQuality_Prnt',
    's1p3_q7d': 'Per_SchQuality_Crowd',
    's1p3_q7e': 'Per_SchQuality_WMBuild',
    's1p3_q7f': 'Per_SchQuality_TeachIntL',
    's1p3_q8': 'Per_AdvSSchCertB',
    's1p3_q9': 'Per_AdvSSchCertG',
    's1p3_q10': 'Per_AdvPSchCertG',
    's1p3_q11': 'Per_AdvPSchCertG',
    's1p3_q12': 'Per_AdvBPS',
    's1p3_q13': 'Per_AdvGPS',
    's1p3_q14': 'Per_AttendSchHH'
}

merged_df.rename(columns=rename_mapping, inplace=True)
'''
# Drop redundant columns
merged_df.drop(merged_df.columns[merged_df.columns.str.contains('Unnamed', case=True)], axis=1, inplace=True)
merged_df.drop(merged_df.columns[merged_df.columns.str.contains(' ', case=False)], axis=1, inplace=True)
'''
# Save the merged dataframe to a CSV file
merged_df.to_csv('2. merged_Education.csv', index=False)
