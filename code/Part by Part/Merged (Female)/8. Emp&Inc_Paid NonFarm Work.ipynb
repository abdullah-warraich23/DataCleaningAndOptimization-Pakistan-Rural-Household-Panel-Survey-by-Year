# %%
# This code block stores file paths to variables to make the code neat
# The stored variables are called in the read_excel function and stored as dataframes

import pandas as pd
import numpy as np

# Store excel file locations to variables (change it as per your path to file)
file_2012=r"C:\Users\warra\Desktop\Freelance\data\data\FemaleMerge\1. Merging by Parts\8. Section 2 Part 4 Paid non farm work\2012_s2p4_f.csv"
file_2013=r"C:\Users\warra\Desktop\Freelance\data\data\FemaleMerge\1. Merging by Parts\8. Section 2 Part 4 Paid non farm work\2013_s2p4_f.csv"
file_2014=r"C:\Users\warra\Desktop\Freelance\data\data\FemaleMerge\1. Merging by Parts\8. Section 2 Part 4 Paid non farm work\2014_s2p4_f.csv"

# Read excel files
df_2012 = pd.read_csv(file_2012)
df_2013 = pd.read_csv(file_2013)
df_2014 = pd.read_csv(file_2014)

# %%
'''
This code block will be used to standardize column names across the years to avoid discrepancies during the merging process.
For example in the roaster data for 2013 rq21 and rq23 are not the same as rq21 and rq23 in 2014 data, but they have the same variable names. Hence, we decide to rename such columns beforehand
We will add the updated name to the mapping dictionaries instead of the original names.

'''

# Rename columns in df_2012
df_2012.rename(columns={
    'pid': 'r_pid',
    'S2P4Q2': 's2p4_q2',
    'S2P4Q3': 's2p4_q3',
    'S2P4Q4MAR': 's2p4_q4_m14',
    'S2P4Q4FEB': 's2p4_q4_f14',
    'S2P4Q4JAN': 's2p4_q4_j14',
    'S2P4Q4DEC': 's2p4_q4_d13',
    'S2P4Q4NOV': 's2p4_q4_n13',
    'S2P4Q4OCT': 's2p4_q4_o13',
    'S2P4Q4SEP': 's2p4_q4_s13',
    'S2P4Q4AUG': 's2p4_q4_a13',
    'S2P4Q4JUL': 's2p4_q4_jul13',
    'S2P4Q4JUN': 's2p4_q4_jun13',
    'S2P4Q4MAY': 's2p4_q4_m13',
    'S2P4Q4APR': 's2p4_q4_ap13',
    'S2P4Q5': 's2p4_q6',
    'S2P4Q6': 's2p4_q7b',
    'S2P4Q11': 's2p4_q10',
    'S2P4Q12MAR': 's2p4_q11_m14',
    'S2P4Q12FEB': 's2p4_q11_f14',
    'S2P4Q12JAN': 's2p4_q11_j14',
    'S2P4Q12DEC': 's2p4_q11_d13',
    'S2P4Q12NOV': 's2p4_q11_n13',
    'S2P4Q12OCT': 's2p4_q11_o13',
    'S2P4Q12SEP': 's2p4_q11_s13',
    'S2P4Q12AUG': 's2p4_q11_a13',
    'S2P4Q12JUL': 's2p4_q11_jul13',
    'S2P4Q12JUN': 's2p4_q11_jun13',
    'S2P4Q12MAY': 's2p4_q11_m13',
    'S2P4Q12APR': 's2p4_q11_ap13',
    'S2P4Q13': 's2p4_q13',
    'S2P4Q14': 's2p4_q14b',
    'S2P4Q19': 's2p4_q16',
    'S2P4Q20': 's2p4_q17',
    'S2P4Q7': 'PNFW_PJ_Wloc',
    'S2P4Q8': 'PNFW_PJWloc_Type',
    'S2P4Q9': 'PNFW_PJWloc_DistH',
    'S2P4Q10': 'PNFW_PJWloc_MoT',
    'S2P4Q15': 'PNFW_SJ_Wloc',
    'S2P4Q16': 'PNFW_SJ_Wloc_Type',
    'S2P4Q17': 'PNFW_SJ_Wloc_Dist',
    'S2P4Q18': 'PNFW_SJ_Wloc_MoT',
    'PROVINCE_ID': 'P_ID',
    'DISTRICT_ID': 'D_ID',
    'TEHSIL_ID': 'T_ID',
    'UC_ID': 'UC_ID',
    'MAUZA_ID': 'M_ID'
}, inplace=True)

# Rename columns in df_2013
df_2013.rename(columns={
    's2p4_q4_m13': 's2p4_q4_m14',
    's2p4_q4_f13': 's2p4_q4_f14',
    's2p4_q4_j13': 's2p4_q4_j14',
    's2p4_q4_d12': 's2p4_q4_d13',
    's2p4_q4_n12': 's2p4_q4_n13',
    's2p4_q4_o12': 's2p4_q4_o13',
    's2p4_q4_s12': 's2p4_q4_s13',
    's2p4_q4_a12': 's2p4_q4_a13',
    's2p4_q4_jul12': 's2p4_q4_jul13',
    's2p4_q4_jun12': 's2p4_q4_jun13',
    's2p4_q4_m12': 's2p4_q4_m13',
    's2p4_q4_ap12': 's2p4_q4_ap13',
    's2p4_q11_m13': 's2p4_q11_m14',
    's2p4_q11_f13': 's2p4_q11_f14',
    's2p4_q11_j13': 's2p4_q11_j14',
    's2p4_q11_d12': 's2p4_q11_d13',
    's2p4_q11_n12': 's2p4_q11_n13',
    's2p4_q11_o12': 's2p4_q11_o13',
    's2p4_q11_s12': 's2p4_q11_s13',
    's2p4_q11_a12': 's2p4_q11_a13',
    's2p4_q11_jul12': 's2p4_q11_jul13',
    's2p4_q11_jun12': 's2p4_q11_jun13',
    's2p4_q11_m12': 's2p4_q11_m13',
    's2p4_q11_ap12': 's2p4_q11_ap13'

}, inplace=True)

# df_2014 doesn't need renaming as it is the reference

# %%
# Updated mappings

mapping_2012 = [
     'hid', 'round', 'r_pid', 's2p4_q2', 's2p4_q3', 's2p4_q4_m14', 's2p4_q4_f14',
    's2p4_q4_j14', 's2p4_q4_d13', 's2p4_q4_n13', 's2p4_q4_o13', 's2p4_q4_s13',
    's2p4_q4_a13', 's2p4_q4_jul13', 's2p4_q4_jun13', 's2p4_q4_m13', 's2p4_q4_ap13',
    None, 's2p4_q6', 's2p4_q7b', None, None, None, 's2p4_q10', 's2p4_q11_m14',
    's2p4_q11_f14', 's2p4_q11_j14', 's2p4_q11_d13', 's2p4_q11_n13', 's2p4_q11_o13',
    's2p4_q11_s13', 's2p4_q11_a13', 's2p4_q11_jul13', 's2p4_q11_jun13', 's2p4_q11_m13',
    's2p4_q11_ap13', None, 's2p4_q13', None, 's2p4_q14b', None, None, 's2p4_q16',
    's2p4_q17', None, None, 'PNFW_PJ_Wloc', 'PNFW_PJWloc_Type', 'PNFW_PJWloc_DistH',
    'PNFW_PJWloc_MoT', 'PNFW_SJ_Wloc', 'PNFW_SJ_Wloc_Type', 'PNFW_SJ_Wloc_Dist',
    'PNFW_SJ_Wloc_MoT', 'P_ID', 'D_ID', 'T_ID', 'UC_ID', 'M_ID'
]

mapping_2013 = [
    'hid', 'round', 'r_pid', 's2p4_q2', 's2p4_q3', 's2p4_q4_m14', 's2p4_q4_f14', 's2p4_q4_j14', 's2p4_q4_d13',
    's2p4_q4_n13', 's2p4_q4_o13', 's2p4_q4_s13', 's2p4_q4_a13', 's2p4_q4_jul13', 's2p4_q4_jun13', 's2p4_q4_m13',
    's2p4_q4_ap13', 's2p4_q5', 's2p4_q6', 's2p4_q7b', 's2p4_q8a', 's2p4_q8b', 's2p4_q9', 's2p4_q10', 's2p4_q11_m14',
    's2p4_q11_f14', 's2p4_q11_j14', 's2p4_q11_d13', 's2p4_q11_n13', 's2p4_q11_o13', 's2p4_q11_s13', 's2p4_q11_a13',
    's2p4_q11_jul13', 's2p4_q11_jun13', 's2p4_q11_m13', 's2p4_q11_ap13', 's2p4_q12', 's2p4_q13', 's2p4_q14a',
    's2p4_q14b', 's2p4_q15a', 's2p4_q15b', 's2p4_q16', 's2p4_q17', None, None, None, None, None, None, None, None, None,
    None, None, None, None, None, None
]

mapping_2014 = [
     'hid', 'round', 'r_pid', 's2p4_q2', 's2p4_q3', 's2p4_q4_m14', 's2p4_q4_f14',
    's2p4_q4_j14', 's2p4_q4_d13', 's2p4_q4_n13', 's2p4_q4_o13', 's2p4_q4_s13',
    's2p4_q4_a13', 's2p4_q4_jul13', 's2p4_q4_jun13', 's2p4_q4_m13', 's2p4_q4_ap13',
    's2p4_q5', 's2p4_q6', 's2p4_q7b', 's2p4_q8a', 's2p4_q8b', 's2p4_q9', 's2p4_q10',
    's2p4_q11_m14', 's2p4_q11_f14', 's2p4_q11_j14', 's2p4_q11_d13', 's2p4_q11_n13',
    's2p4_q11_o13', 's2p4_q11_s13', 's2p4_q11_a13', 's2p4_q11_jul13', 's2p4_q11_jun13',
    's2p4_q11_m13', 's2p4_q11_ap13', 's2p4_q12', 's2p4_q13', 's2p4_q14a', 's2p4_q14b',
    's2p4_q15a', 's2p4_q15b', 's2p4_q16', 's2p4_q17', 's2p4_q18', 's2p4_q19',
    None, None, None, None, None, None, None, None, None, None, None, None, None
]

# %%
# Create a list of all possible columns in the correct order
all_columns = []

for col in mapping_2012:
    if col and col not in all_columns:
        all_columns.append(col)   
for col in mapping_2013:
    if col and col not in all_columns:
        all_columns.append(col)
for col in mapping_2014:
    if col and col not in all_columns:
        all_columns.append(col)

# %%
def standardize_and_merge(dfs, mappings, all_columns):
    merged_data = {col: [] for col in all_columns}

    for df, mapping in zip(dfs, mappings):
        print(f"Processing DataFrame with columns: {df.columns.tolist()}")
        for i, col in enumerate(mapping):
            if col:
                ref_col = col.strip()  # Remove leading/trailing whitespace
                if ref_col not in merged_data:
                    merged_data[ref_col] = []
                if ref_col in df.columns:
                    print(f"Appending data for column {ref_col}")
                    if isinstance(df[ref_col], pd.Series):
                        merged_data[ref_col].extend(df[ref_col].tolist())
                    elif isinstance(df[ref_col], pd.DataFrame):
                        print(f"Column {ref_col} is duplicated in DataFrame. Appending data for each duplicate.")
                        for _, series in df[ref_col].items():
                            merged_data[ref_col].extend(series.tolist())
                else:
                    print(f"Column {ref_col} not found in DataFrame. Adding NaNs.")
                    merged_data[ref_col].extend([np.nan] * len(df))
    
    max_len = max(len(v) for v in merged_data.values())
    for key in merged_data:
        col_len = len(merged_data[key])
        if col_len < max_len:
            merged_data[key].extend([np.nan] * (max_len - col_len))

    merged_df = pd.DataFrame.from_dict(merged_data)
    return merged_df

# %%
# Usage with dataframes and mappings
dfs = [df_2012, df_2013, df_2014]
mappings = [mapping_2012, mapping_2013, mapping_2014]

merged_df = standardize_and_merge(dfs, mappings, all_columns)
# Out:
# Processing DataFrame with columns: ['Unnamed: 0.1', 'Unnamed: 0', 'hid', 'round', 'r_pid', 's2p4_q2', 's2p4_q3', 's2p4_q4_j14', 's2p4_q4_f14', 's2p4_q4_m14', 's2p4_q4_ap13', 's2p4_q4_m13', 's2p4_q4_jun13', 's2p4_q4_jul13', 's2p4_q4_a13', 's2p4_q4_s13', 's2p4_q4_o13', 's2p4_q4_n13', 's2p4_q4_d13', 's2p4_q6', 's2p4_q7b', 'PNFW_PJ_Wloc', 'PNFW_PJWloc_Type', 'PNFW_PJWloc_DistH', 'PNFW_PJWloc_MoT', 's2p4_q10', 's2p4_q11_j14', 's2p4_q11_f14', 's2p4_q11_m14', 's2p4_q11_ap13', 's2p4_q11_m13', 's2p4_q11_jun13', 's2p4_q11_jul13', 's2p4_q11_a13', 's2p4_q11_s13', 's2p4_q11_o13', 's2p4_q11_n13', 's2p4_q11_d13', 's2p4_q13', 's2p4_q14b', 'PNFW_SJ_Wloc', 'PNFW_SJ_Wloc_Type', 'PNFW_SJ_Wloc_Dist', 'PNFW_SJ_Wloc_MoT', 's2p4_q16', 's2p4_q17', 'P_ID', 'D_ID', 'T_ID', 'UC_ID', 'M_ID']
# Appending data for column hid
# Appending data for column round
# Appending data for column r_pid
# Appending data for column s2p4_q2
# Appending data for column s2p4_q3
# Appending data for column s2p4_q4_m14
# ...

# %%
# Rename columns for the merged file (if needed)
rename_mapping = {
    'hid': 'HID',
    'round': 'Survey_Round',
    'r_pid': 'PID',
    's2p4_q2': 'PNFW_12m',
    's2p4_q3': 'PNFW_PJ_EmpStatus',
    's2p4_q4_m14': 'PNFW_PJ_DpM_Mar',
    's2p4_q4_f14': 'PNFW_PJ_DpM_Feb',
    's2p4_q4_j14': 'PNFW_PJ_DpM_Jan',
    's2p4_q4_d13': 'PNFW_PJ_DpM_Dec',
    's2p4_q4_n13': 'PNFW_PJ_DpM_Nov',
    's2p4_q4_o13': 'PNFW_PJ_DpM_Oct',
    's2p4_q4_s13': 'PNFW_PJ_DpM_Sep',
    's2p4_q4_a13': 'PNFW_PJ_DpM_Aug',
    's2p4_q4_jul13': 'PNFW_PJ_DpM_Jul',
    's2p4_q4_jun13': 'PNFW_PJ_DpM_Jun',
    's2p4_q4_m13': 'PNFW_PJ_DpM_May',
    's2p4_q4_ap13': 'PNFW_PJ_DpM_Apr',
    's2p4_q5': 'PNFW_PJ_PoP',
    's2p4_q6': 'PNFW_PJ_TE',
    's2p4_q7b': 'PNFW_PJ_Nature',
    's2p4_q8a': 'PNFW_PJ_EA_Des',
    's2p4_q8b': 'PNFW_PJ_EA_Code',
    's2p4_q9': 'PNFW_SJ_YN',
    's2p4_q10': 'PNFW_SJ_EmpStatus',
    's2p4_q11_m14': 'PNFW_SJ_DpM_Mar',
    's2p4_q11_f14': 'PNFW_SJ_DpM_Feb',
    's2p4_q11_j14': 'PNFW_SJ_DpM_Jan',
    's2p4_q11_d13': 'PNFW_SJ_DpM_Dec',
    's2p4_q11_n13': 'PNFW_SJ_DpM_Nov',
    's2p4_q11_o13': 'PNFW_SJ_DpM_Oct',
    's2p4_q11_s13': 'PNFW_SJ_DpM_Sep',
    's2p4_q11_a13': 'PNFW_SJ_DpM_Aug',
    's2p4_q11_jul13': 'PNFW_SJ_DpM_Jul',
    's2p4_q11_jun13': 'PNFW_SJ_DpM_Jun',
    's2p4_q11_m13': 'PNFW_SJ_DpM_May',
    's2p4_q11_ap13': 'PNFW_SJ_DpM_Apr',
    's2p4_q12': 'PNFW_SJ_PoP',
    's2p4_q13': 'PNFW_SJ_TE',
    's2p4_q14a': 'PNFW_SJ_Des',
    's2p4_q14b': 'PNFW_SJ_Code',
    's2p4_q15a': 'PNFW_SJ_EA_Des',
    's2p4_q15b': 'PNFW_SJ_EA_Code',
    's2p4_q16': 'PNFW_SJ_HC',
    's2p4_q17': 'PNFW_SJ_pp',
    's2p4_q18': 'PNFW_SJ_pp_12m',
    's2p4_q19': 'PNFW_SJ_pp_Val'
}

merged_df.rename(columns=rename_mapping, inplace=True)
'''
# Drop redundant columns
merged_df.drop(merged_df.columns[merged_df.columns.str.contains('Unnamed', case=True)], axis=1, inplace=True)
merged_df.drop(merged_df.columns[merged_df.columns.str.contains(' ', case=False)], axis=1, inplace=True)
'''
# Save the merged dataframe to a CSV file
merged_df.to_csv('6. merged_EnI_Paid Non-Farm Work.csv', index=False)
