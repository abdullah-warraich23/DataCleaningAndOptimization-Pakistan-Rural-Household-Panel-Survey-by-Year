# %%
# This code block stores file paths to variables to make the code neat
# The stored variables are called in the read_excel function and stored as dataframes

import pandas as pd
import numpy as np
# Store excel file locations to variables

Com_2012 = r"C:\Users\warra\Desktop\Freelance\data\data\CommunityMerge\1. Merging by Parts\13. S8 Basic Community Characteristics and Infrastructure\2012_s2.csv"

# Read excel files 
df_2012 = pd.read_csv(Com_2012)

# %%
# Rename columns for the merged file (if needed)
rename_mapping = {
    'round': 'Survey_Round',
    'cid': 'CID',
    'community': 'Community',
    'S2Q1A': 'CCI_NoHH',
    'S2Q1B': 'CCI_NoHH_5y',
    'S2Q2A': 'CCI_TP',
    'S2Q2B': 'CCI_TP_5y',
    'S2Q3A': 'CCI_RSI',
    'S2Q3C': 'CCI_RSI_FIntro',
    'S2Q4A': 'CCI_RSE',
    'S2Q4C': 'CCI_RSE_FIntro',
    'S2Q5A': 'CCI_NCMR',
    'S2Q6A': 'CCI_NC_Name',
    'S2Q7A': 'CCI_NC_DistKM',
    'S2Q8A': 'CCI_MoT',
    'S2Q8B': 'CCI_MoT_5y',
    'S2Q9A': 'CCI_MoT_NCTime',
    'S2Q10A': 'CCI_PT_VtNC',
    'S2Q10B': 'CCI_PTVtNC_5y',
    'S2Q11A': 'CCI_PTVtNC_CostRs',
    'S2Q11B': 'CCI_PTVtNC_CPPR_5y',
    'S2Q12A': 'CCI_HHMark',
    'S2Q13A': 'CCI_CC_DistKM',
    'S2Q14A': 'CCI_CC_Name',
    'S2Q15A': 'CCI_CC_TimeMins',
    'S2Q15B': 'CCI_CC_TimeMins_5y',
    'S2Q16A': 'CCI_PTVtCC',
    'S2Q16B': 'CCI_PTVtCC_5y',
    'S2Q17A': 'CCI_PTVtCC_CostRs',
    'S2Q17B': 'CCI_PTVtCC_CostRs_5y',
    'S2Q18A': 'CCI_PO_DistKM',
    'S2Q18B': 'CCI_PO_DistKM_5y',
    'S2Q19A': 'CCI_RS',
    'S2Q19B': 'CCI_RS_5y',
    'S2Q20A': 'CCI_VElec',
    'S2Q20B': 'CCI_VElec_5y',
    'S2Q20C': 'CCI_VElec_FIntro',
    'S2Q21A': 'CCI_NBEC',
    'S2Q21B': 'CCI_NBEC_5y',
    'S2Q22A': 'CCI_UnoffFees',
    'S2Q23A': 'CCI_UnoffFees_Cost',
    'S2Q24A': 'CCI_HHGas',
    'S2Q24B': 'CCI_HHGas_5y',
    'S2Q24C': 'CCI_HHGas_FIntro',
    'S2Q25A': 'CCI_HHSGas',
    'S2Q25B': 'CCI_HHSGas_5y',
    'S2Q25C': 'CCI_HHSGas_FIntro',
    'S2Q26A': 'CCI_Tele',
    'S2Q26C': 'CCI_Tele_5y',
    'S2Q27A': 'CCI_NBtele',
    'S2Q27B': 'CCI_Nbtele_5y',
    'S2Q28A': 'CCI_Cell',
    'S2Q28C': 'CCI_Cell_FIntro',
    'S2Q29A': 'CCI_Sew',
    'S2Q29C': 'CCI_Sew_FIntro',
    'S2Q30A': 'CCI_DS',
    'S2Q30C': 'CCI_DS_FIntro',
    'fid': 'FID',
    'PROVINCE_ID': 'P_ID',
    'DISTRICT_ID': 'D_ID',
    'TEHSIL_ID': 'T_ID',
    'UC_ID': 'UC_ID',
    'MAUZA_ID': 'M_ID',
    'S2Q31A': 'CCI_HH_0Acer',
    'S2Q31B': 'CCI_HH_1Acer',
    'S2Q31C': 'CCI_HH_2Acer',
    'S2Q31D': 'CCI_HH_5Acer',
    'S2Q31E': 'CCI_HH_mt5Acer'
}


df_2012.rename(columns=rename_mapping, inplace=True)

# Drop redundant columns
df_2012.drop(df_2012.columns[df_2012.columns.str.contains('Unnamed', case=True)], axis=1, inplace=True)
df_2012.drop(df_2012.columns[df_2012.columns.str.contains(' ', case=False)], axis=1, inplace=True)

# Save the merged dataframe to a CSV file
df_2012.to_csv('11. merged_S10_Basic Community Characteristics and Infrastructure.csv', index=False)
