# %%
'''
This notebook contains the code to merge all male data across the years based on sections.
There are datasets for 2012, 2012-1.5, 2013 and 2014
The different sections that will be merged are as follows:
**2012**
1. Cover
2. Roaster
3. Section 1: Education (All men 18 and above)
4. Section 2: Agriculture
5. Section 3: Assets
6. Section 4: Consumption and Expenditure
7. Section 5: Credit
8. Section 6: Employment and Income
9. Section 7: Economic Events/Shocks
10. Section 8: Community Participation and Social Network Membership

**2013**
1. Cover
2. Roaster
3. Section 1: Education: Males 19 years and older
4. Section 2: Agriculture
5. Section 3: Assets
6. Section 4: Consumption and Expenditure
7. Section 5: Credit
8. Section 6: Employment and Income
9. Section 7: Health
10. Section 8: Political Participation and Governance

**2014**
1. Cover
2. Roaster
3. Section 1: Education: Males 19 years and older
4. Section 2: Agriculture
5. Section 3: Assets
6. Section 4: Consumption and Expenditure
7. Section 5: Credit
8. Section 6: Employment and Income
9. Section 7: Economic Events/Shocks”
10. Section 8: Participation in Social Safety Net
11. Section 9: Siblings
12. Section 10: Transfers
13. Section 11: Health and Nutrition

'''

# %%
# This code block stores file paths to variables to make the code neat
# The stored variables are called in the read_excel function and stored as dataframes

import pandas as pd
import numpy as np
# Store excel file locations to variables
EI_2012 = r"C:\Users\warra\Desktop\Freelance\data\data\MaleMerge\30. Section 7 Part 1 Ecom Events and shocks - Negative shocks\2012_s7p2_m.xlsx"
EI_2013 = r"C:\Users\warra\Desktop\Freelance\data\data\MaleMerge\30. Section 7 Part 1 Ecom Events and shocks - Negative shocks\2013_s9p1_m.xlsx"
EI_2014 = r"C:\Users\warra\Desktop\Freelance\data\data\MaleMerge\30. Section 7 Part 1 Ecom Events and shocks - Negative shocks\2014_s7p1_m.xlsx"

# Read excel files 
df_2012 = pd.read_excel(EI_2012)
df_2013 = pd.read_excel(EI_2013)
df_2014 = pd.read_excel(EI_2014)

# %%
#This code block will be used to standardize column names across the years to avoid discrepancies during the merging process.

# Rename columns in df to df_2014 column names


df_2012.rename(columns={
    'shock_id': 's7p1_code',
    'S7P2Q1': 's7p1_q7',
    'S7P2Q2A': 's7p1_q8_a',
    'S7P2Q2B': 's7p1_q8_b',
    'S7P2Q2C': 's7p1_q8_c',
    'PROVINCE_ID': 'P_ID',
    'DISTRICT_ID': 'D_ID',
    'TEHSIL_ID': 'T_ID',
    'MAUZA_ID': 'M_ID'
}, inplace=True)

df_2013.rename(columns={
    's9p1_code': 's7p1_code',
    's9p1_shocks': 's7p1_shocks',
    's9p1_q1': 's7p1_q1',
    's9p1_q2': 's7p1_q2',
    's9p1_q4_1': 's7p1_q3_1',
    's9p1_q4_2': 's7p1_q3_2',
    's9p1_q4_3': 's7p1_q3_3',
    's9p1_q4_4': 's7p1_q3_4',
    's9p1_q4_5': 's7p1_q3_5',
    's9p1_q4_6': 's7p1_q3_6',
    's9p1_q5': 's7p1_q4',
    's9p1_q7': 's7p1_q5',
    's9p1_q8': 's7p1_q6',
    's9p1_q9': 's7p1_q7',
    's9p1_q10_1': 's7p1_q8_a',
    's9p1_q10_2': 's7p1_q8_b',
    's9p1_q10_3': 's7p1_q8_c',
    's9p1_q3': 'Shock_No5Year'
    
}, inplace=True)


# df_2014 doesn't need renaming as it is the reference

# %%
# Define the column mappings based on the provided positions
# Make dictionaries for each year with updated names
# replace with 'None' where there are no columns
#Here are the updated mapping lists for the given datasets:


mapping_2012 = [
    'hid', 'round', 's7p1_code', None, None, None, None, None, None, 
    None, None, None, None, None, None, 's7p1_q7', 's7p1_q8_a', 's7p1_q8_b', 
    's7p1_q8_c', None, None, 'P_ID', 'D_ID', 'T_ID', 'UC_ID', 'M_ID'
]

mapping_2013 = [
    'hid', 'round', 's7p1_code', 's7p1_shocks', 's7p1_q1', 's7p1_q2', 
    's7p1_q3_1', 's7p1_q3_2', 's7p1_q3_3', 's7p1_q3_4', 's7p1_q3_5', 
    's7p1_q3_6', 's7p1_q4', 's7p1_q5', 's7p1_q6', 's7p1_q7', 's7p1_q8_a', 
    's7p1_q8_b', 's7p1_q8_c', 's7p1_q9','Shock_No5Year', None, None, None, None, None
]

mapping_2014 = [
    'hid', 'round', 's7p1_code', 's7p1_shocks', 's7p1_q1', 's7p1_q2', 
    's7p1_q3_1', 's7p1_q3_2', 's7p1_q3_3', 's7p1_q3_4', 's7p1_q3_5', 
    's7p1_q3_6', 's7p1_q4', 's7p1_q5', 's7p1_q6', 's7p1_q7', 's7p1_q8_a', 
    's7p1_q8_b', 's7p1_q8_c', 's7p1_q9', None, None, None, None, None, None, None
]

# %%
# Create a list of all possible columns in the correct order
all_columns = []

for col in mapping_2012:
    if col and col not in all_columns:
        all_columns.append(col) 
   
for col in mapping_2013:
    if col and col not in all_columns:
        all_columns.append(col)
for col in mapping_2014:
    if col and col not in all_columns:
        all_columns.append(col)

# %%
def standardize_and_merge(dfs, mappings, all_columns):
    merged_data = {col: [] for col in all_columns}

    for df, mapping in zip(dfs, mappings):
        print(f"Processing DataFrame with columns: {df.columns.tolist()}")
        for i, col in enumerate(mapping):
            if col:
                ref_col = col.strip()  # Remove leading/trailing whitespace
                if ref_col not in merged_data:
                    merged_data[ref_col] = []
                if ref_col in df.columns:
                    print(f"Appending data for column {ref_col}")
                    if isinstance(df[ref_col], pd.Series):
                        merged_data[ref_col].extend(df[ref_col].tolist())
                    elif isinstance(df[ref_col], pd.DataFrame):
                        print(f"Column {ref_col} is duplicated in DataFrame. Appending data for each duplicate.")
                        for _, series in df[ref_col].items():
                            merged_data[ref_col].extend(series.tolist())
                else:
                    print(f"Column {ref_col} not found in DataFrame. Adding NaNs.")
                    merged_data[ref_col].extend([np.nan] * len(df))
    
    max_len = max(len(v) for v in merged_data.values())
    for key in merged_data:
        col_len = len(merged_data[key])
        if col_len < max_len:
            merged_data[key].extend([np.nan] * (max_len - col_len))

    merged_df = pd.DataFrame.from_dict(merged_data)
    return merged_df

# %%
# Usage with dataframes and mappings
dfs = [ df_2012, df_2013, df_2014]
mappings = [ mapping_2012, mapping_2013, mapping_2014]

merged_df = standardize_and_merge(dfs, mappings, all_columns)
# Out:
# Processing DataFrame with columns: ['Unnamed: 0', 'hid', 'round', 's7p1_code', 's7p1_q7', 's7p1_q8_a', 's7p1_q8_b', 's7p1_q8_c', 'P_ID', 'D_ID', 'T_ID', 'UC_ID', 'M_ID']
# Appending data for column hid
# Appending data for column round
# Appending data for column s7p1_code
# Appending data for column s7p1_q7
# Appending data for column s7p1_q8_a
# Appending data for column s7p1_q8_b
# Appending data for column s7p1_q8_c
# Appending data for column P_ID
# Appending data for column D_ID
# Appending data for column T_ID
# Appending data for column UC_ID
# Appending data for column M_ID
# Processing DataFrame with columns: ['Unnamed: 0', 'hid', 'round', 's7p1_code', 's7p1_shocks', 's7p1_q1', 's7p1_q2', 'Shock_No5Year', 's7p1_q3_1', 's7p1_q3_2', 's7p1_q3_3', 's7p1_q3_4', 's7p1_q3_5', 's7p1_q3_6', 's7p1_q4', 's9p1_q6', 's7p1_q5', 's7p1_q6', 's7p1_q7', 's7p1_q8_a', 's7p1_q8_b', 's7p1_q8_c']
# Appending data for column hid
# Appending data for column round
# Appending data for column s7p1_code
# Appending data for column s7p1_shocks
# Appending data for column s7p1_q1
# Appending data for column s7p1_q2
# Appending data for column s7p1_q3_1
# Appending data for column s7p1_q3_2
# Appending data for column s7p1_q3_3
# Appending data for column s7p1_q3_4
# Appending data for column s7p1_q3_5
# Appending data for column s7p1_q3_6
# Appending data for column s7p1_q4
# Appending data for column s7p1_q5
# Appending data for column s7p1_q6
# Appending data for column s7p1_q7
# Appending data for column s7p1_q8_a
# Appending data for column s7p1_q8_b
# Appending data for column s7p1_q8_c
# Column s7p1_q9 not found in DataFrame. Adding NaNs.
# Appending data for column Shock_No5Year
# Processing DataFrame with columns: ['Unnamed: 0', 'hid', 'round', 's7p1_code', 's7p1_shocks', 's7p1_q1', 's7p1_q2', 's7p1_q3_1', 's7p1_q3_2', 's7p1_q3_3', 's7p1_q3_4', 's7p1_q3_5', 's7p1_q3_6', 's7p1_q4', 's7p1_q5', 's7p1_q6', 's7p1_q7', 's7p1_q8_a', 's7p1_q8_b', 's7p1_q8_c', 's7p1_q9']
# Appending data for column hid
# Appending data for column round
# Appending data for column s7p1_code
# Appending data for column s7p1_shocks
# Appending data for column s7p1_q1
# Appending data for column s7p1_q2
# Appending data for column s7p1_q3_1
# Appending data for column s7p1_q3_2
# Appending data for column s7p1_q3_3
# Appending data for column s7p1_q3_4
# Appending data for column s7p1_q3_5
# Appending data for column s7p1_q3_6
# Appending data for column s7p1_q4
# Appending data for column s7p1_q5
# Appending data for column s7p1_q6
# Appending data for column s7p1_q7
# Appending data for column s7p1_q8_a
# Appending data for column s7p1_q8_b
# Appending data for column s7p1_q8_c
# Appending data for column s7p1_q9

# %%
# Rename columns for the merged file (if needed)
rename_mapping = {
     'hid': 'HID',
    'round': 'Survey_Round',
    's7p1_code': 'Shock_ID',
    's7p1_shocks': 'Shock_Name',
    's7p1_q1': 'Shock_Indicate',
    's7p1_q2': 'Shock_Eff_YN',
    's7p1_q3_1': 'Shock_Cause1',
    's7p1_q3_2': 'Shock_Cause2',
    's7p1_q3_3': 'Shock_Cause3',
    's7p1_q3_4': 'Shock_Cause4',
    's7p1_q3_5': 'Shock_Cause5',
    's7p1_q3_6': 'Shock_Cause6',
    's7p1_q4': 'Shock_Affect',
    's7p1_q5': 'Shock_No1Year',
    's7p1_q6': 'Shock_Last',
    's7p1_q7': 'Shock_LossT',
    's7p1_q8_a': 'Shock_Cope1',
    's7p1_q8_b': 'Shock_Cope2',
    's7p1_q8_c': 'Shock_Cope3',
    's7p1_q9': 'Shock_Rank'
}

merged_df.rename(columns=rename_mapping, inplace=True)

# Save the merged dataframe to a CSV file
merged_df.to_csv('merged_Section_7_part_1.csv', index=False)
