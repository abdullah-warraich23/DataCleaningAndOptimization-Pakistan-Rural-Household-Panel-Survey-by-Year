# %%
# This code block stores file paths to variables to make the code neat
# The stored variables are called in the read_excel function and stored as dataframes

import pandas as pd
import numpy as np

# Store excel file locations to variables (change it as per your path to file)
file_2012=r"C:\Users\warra\Desktop\Freelance\data\data\FemaleMerge\1. Merging by Parts\31. Section 8 Part 2 Health and Nutrition Children Anthropometry and IYCF practices\2012_s5P3.csv"
file_2013=r"C:\Users\warra\Desktop\Freelance\data\data\FemaleMerge\1. Merging by Parts\31. Section 8 Part 2 Health and Nutrition Children Anthropometry and IYCF practices\2013_s4p2_f.csv"
file_2014=r"C:\Users\warra\Desktop\Freelance\data\data\FemaleMerge\1. Merging by Parts\31. Section 8 Part 2 Health and Nutrition Children Anthropometry and IYCF practices\2014_s8P2P3.csv"

# Read excel files
df_2012 = pd.read_csv(file_2012)
df_2013 = pd.read_csv(file_2013)
df_2014 = pd.read_csv(file_2014)

# %%
'''
This code block will be used to standardize column names across the years to avoid discrepancies during the merging process.
For example in the roaster data for 2013 rq21 and rq23 are not the same as rq21 and rq23 in 2014 data, but they have the same variable names. Hence, we decide to rename such columns beforehand
We will add the updated name to the mapping dictionaries instead of the original names.

'''

# Rename columns in df_2012
df_2012.rename(columns={
    'pid': 'r_pid',
    'S5_P3_Q_2': 's8p2_q2',
    'S5_P3_Q_7': 's8p2_q4',
    'S6P2AQ2': 's8p3a_q2',
    'S6P2AQ3': 's8p3a_q3',
    'S6P2AQ11': 's8p3a_q4',
    'S5_P3_Q_11': 's8p3a_q5',
    'S6P2AQ14': 's8p3a_q6',
    'S6P2AQ15': 's8p3a_q7',
    'S6P2BQ4': 's8p3b_q2',
    'S6P2BQ13': 's8p3b_q3',
    'S6P2BQ14': 's8p3b_q4',
    'S6P2BQ15': 's8p3b_q5',
    'S6P2BQ16': 's8p3b_q6',
    'S6P2BQ17': 's8p3b_q7',
    'S6P2BQ18': 's8p3b_q8',
    'S6P2BQ19': 's8p3b_q9',
    'S6P2BQ20': 's8p3b_q10',
    'S6P2BQ21': 's8p3b_q11',
    'S6P2BQ23': 's8p3b_q16',
    'S6P2BQ24': 's8p3b_q17',
    'S6P2BQ25': 's8p3b_q18',
    'S6P2BQ26': 's8p3b_q19',
    'S6P2BQ27': 's8p3b_q20',
    'S6P2BQ28': 's8p3b_q21',
    'S6P2BQ29': 's8p3b_q22',
    'S6P2BQ30': 's8p3b_q23',
    'S6P2BQ7': 'IYCS_Water',
    'S6P2BQ6': 'IYCS_BabyForm',
    'S6P2BQ8': 'IYCS_MilkPF',
    'S6P2BQ9': 'IYCS_FruitJuice',
    'S6P2BQ11': 'IYCS_WBL',
    'S5_P3_Q_3': 'CA_DOB_d',
    'S5_P3_Q_4': 'CA_DOB_w',
    'S5_P3_Q_5': 'CA_DOB_m',
    'S5_P3_Q_6': 'CA_DOB_y',
    'S6P2AQ5': 'IYCF_Sugar_3d',
    'S6P2AQ4': 'IYCF_Honey_3d',
    'S6P2AQ6': 'IYCF_Glucose_3d',
    'S6P2AQ7': 'IYCF_Tea_3d',
    'S6P2AQ8': 'IYCF_CowMilk_3d',
    'S6P2AQ9': 'IYCF_BreastMilk_3d',
    'S6P2AQ10': 'IYCF_Other_3d',
    'S6P2AQ13': '2012_S6P2AQ13_3d',
    'S6P2AQ16': 'IYCF_WaterAge_m',
    'S6P2AQ17': 'IYCF_NonBMAge_m',
    'S6P2AQ18': 'IYCF_CowMilkAge_m',
    'S6P2AQ19': 'IYCF_SDCAge_m',
    'S6P2AQ20': 'IYCF_SSFAge_m',
    'S6P2AQ21': 'IYCF_SFAge_m',
    'S6P2AQ22': 'IYCF_MeatAge_m',
    'S6P2AQ23': 'IYCF_HBEggAge_m',
    'S6P2AQ24': 'IYCF_OFruitVegAge_m',
    'S6P2AQ25': 'IYCF_SnacksAge_m',
    'S6P2AQ26': 'IYCF_RegMEalAge_m',
    'S6P2BQ2': 'ICYF_BreastFeed_NoTy',
    'S6P2BQ3': 'ICYF_MFoY_NoTy',
    'PROVINCE_ID': 'P_ID',
    'DISTRICT_ID': 'D_ID',
    'TEHSIL_ID': 'T_ID',
    'UC_ID': 'UC_ID',
    'MAUZA_ID': 'M_ID',
    'S6P2BQ5': 'ICYF_BreastMilk',
    'S6P2BQ10': 'ICYF_PFJ',
    'S6P2BQ12': 'ICYF_BabyBottle_1d',
    'S6P2BQ22': 'ICYF_AllMeats',
    'S6P2BQ31': 'ICYF_IronTab',
    'S6P2BQ33': 'ICYF_OVoMS_6m',
    'S6P2BQ34': 'ICYF_VoMS_1m',
    'S6P2BQ35': 'ICYF_VS_Name',
    'S6P2BQ36': 'ICYF_SeeEmptyBot',
    'S6P2BQ37_1': 'ICYF_CVoMS1_1w',
    'S6P2BQ37_2': 'ICYF_CVoMS2_1w',
    'S6P2BQ37_3': 'ICYF_CVoMS3_1w',
    'S6P2BQ37_4': 'ICYF_CVoMS4_1w',
    'S6P2BQ37_5': 'ICYF_CVoMS5_1w',
    'S6P2BQ37_6': 'ICYF_CVoMS6_1w',
    'S6P2BQ37_7': 'ICYF_CVoMS7_1w',
    'S6P2BQ37_8': 'ICYF_CVoMS8_1w',
    'S6P2BQ37_9': 'ICYF_CVoMS9_1w'
}, inplace=True)

# Rename columns in df_2013
df_2013.rename(columns={
    'mother_pid': 's8p2_q2',
    's4p2_q3': 's8p2_q3',
    's4p2_q4': 's8p2_q4',
    's4p2_q5': 's8p2_q5_wieght',
    's4p2_q6': 's8p2_q6_height',
    's4p2_q7': 's8p2_q7',
    's4p2_q8': 's8p3a_q5',
    's4p2_q9': 's8p3a_q6',
    's4p2_q10': 's8p3a_q8',
    's4p2_q13': 's8p3a_q9',
    's4p2_q14a': 's8p3a_q10',
    's4p2_q11': 'IYCS_CSuppStartAge',
    's4p2_q12a': 'IYCS_Water',
    's4p2_q12b': 'IYCS_BabyForm',
    's4p2_q12c': 'IYCS_MilkPF',
    's4p2_q12d': 'IYCS_FruitJuice',
    's4p2_q12e': 'IYCS_WBL',
    's4p2_q14b': 'IYCS_SafeLiq2',
    's4p2_q14c': 'IYCS_SafeLiq3'
}, inplace=True)

# df_2014 doesn't need renaming as it is the reference

# %%
# Updated mappings

mapping_2012 = [
    'hid', 'round', 'r_pid', 's8p2_q2', None, 's8p2_q4', None, None, None, 's8p3a_q2', 's8p3a_q3', 's8p3a_q4',
    's8p3a_q5', 's8p3a_q6', 's8p3a_q7', None, None, None, None, None, 's8p3b_q2', 's8p3b_q3', 's8p3b_q4', 
    's8p3b_q5', 's8p3b_q6', 's8p3b_q7', 's8p3b_q8', 's8p3b_q9', 's8p3b_q10', 's8p3b_q11', None, None, None, 
    None, 's8p3b_q16', 's8p3b_q17', 's8p3b_q18', 's8p3b_q19', 's8p3b_q20', 's8p3b_q21', 's8p3b_q22', 's8p3b_q23', None, 
    'IYCS_Water', 'IYCS_BabyForm', 'IYCS_MilkPF', 'IYCS_FruitJuice', 'IYCS_WBL', None, None, 'CA_DOB_d', 
    'CA_DOB_w', 'CA_DOB_m', 'CA_DOB_y', 'IYCF_Sugar_3d', 'IYCF_Honey_3d', 'IYCF_Glucose_3d', 'IYCF_Tea_3d', 
    'IYCF_CowMilk_3d', 'IYCF_BreastMilk_3d', 'IYCF_Other_3d', '2012_S6P2AQ13_3d', 'IYCF_WaterAge_m', 
    'IYCF_NonBMAge_m', 'IYCF_CowMilkAge_m', 'IYCF_SDCAge_m', 'IYCF_SSFAge_m', 'IYCF_SFAge_m', 'IYCF_MeatAge_m', 
    'IYCF_HBEggAge_m', 'IYCF_OFruitVegAge_m', 'IYCF_SnacksAge_m', 'IYCF_RegMEalAge_m', 'ICYF_BreastFeed_NoTy', 'ICYF_MFoY_NoTy', 
    'P_ID', 'D_ID', 'T_ID', 'UC_ID', 'M_ID', 'ICYF_BreastMilk', 'ICYF_PFJ', 'ICYF_BabyBottle_1d', 'ICYF_AllMeats', 
    'ICYF_IronTab', 'ICYF_OVoMS_6m', 'ICYF_VoMS_1m', 'ICYF_VS_Name', 'ICYF_SeeEmptyBot', 'ICYF_CVoMS1_1w', 
    'ICYF_CVoMS2_1w', 'ICYF_CVoMS3_1w', 'ICYF_CVoMS4_1w', 'ICYF_CVoMS5_1w', 'ICYF_CVoMS6_1w', 'ICYF_CVoMS7_1w', 
    'ICYF_CVoMS8_1w', 'ICYF_CVoMS9_1w'
]

mapping_2013 = [
    'hid', 'round', 'r_pid', 's8p2_q2',  's8p2_q3', 's8p2_q4', 's8p2_q5_wieght',
    's8p2_q6_height', 's8p2_q7', None, None, None,  's8p3a_q5',
    's8p3a_q6', None,  's8p3a_q8', 's8p3a_q9', 's8p3a_q10', None, None, 
    None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 
    None, None, None, None, None, None, 'IYCS_CSuppStartAge', 
    'IYCS_Water', 'IYCS_BabyForm', 'IYCS_MilkPF', 'IYCS_FruitJuice', 'IYCS_WBL', 'IYCS_SafeLiq2', 'IYCS_SafeLiq3', None, None, None, None, None, 
    None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 
    None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 
    None, None, None, None, None, None, None, None, None, None, None 
]

mapping_2014 = [
    'hid', 'round', 'r_pid', 's8p2_q2', 's8p2_q3', 's8p2_q4', 's8p2_q5_wieght',
    's8p2_q6_height', 's8p2_q7', 's8p3a_q2', 's8p3a_q3', 's8p3a_q4', 's8p3a_q5',
    's8p3a_q6', 's8p3a_q7', 's8p3a_q8', 's8p3a_q9', 's8p3a_q10', 's8p3a_q11',
    's8p3a_q12', 's8p3b_q2', 's8p3b_q3', 's8p3b_q4', 's8p3b_q5', 's8p3b_q6',
    's8p3b_q7', 's8p3b_q8', 's8p3b_q9', 's8p3b_q10', 's8p3b_q11', 's8p3b_q12',
    's8p3b_q13', 's8p3b_q14', 's8p3b_q15', 's8p3b_q16', 's8p3b_q17', 's8p3b_q18',
    's8p3b_q19', 's8p3b_q20', 's8p3b_q21', 's8p3b_q22', 's8p3b_q23',
    None, None, None, None, None, None, None, None, None, None,
    None, None, None, None, None, None, None, None, None, None,
    None, None, None, None, None, None, None, None, None, None,
    None, None, None, None, None, None, None, None, None, None,
    None, None, None, None, None, None, None, None, None, None,
    None, None, None, None, None, None
]

# %%
# Create a list of all possible columns in the correct order
all_columns = []

for col in mapping_2012:
    if col and col not in all_columns:
        all_columns.append(col)   
for col in mapping_2013:
    if col and col not in all_columns:
        all_columns.append(col)
for col in mapping_2014:
    if col and col not in all_columns:
        all_columns.append(col)

# %%
def standardize_and_merge(dfs, mappings, all_columns):
    merged_data = {col: [] for col in all_columns}

    for df, mapping in zip(dfs, mappings):
        print(f"Processing DataFrame with columns: {df.columns.tolist()}")
        for i, col in enumerate(mapping):
            if col:
                ref_col = col.strip()  # Remove leading/trailing whitespace
                if ref_col not in merged_data:
                    merged_data[ref_col] = []
                if ref_col in df.columns:
                    print(f"Appending data for column {ref_col}")
                    if isinstance(df[ref_col], pd.Series):
                        merged_data[ref_col].extend(df[ref_col].tolist())
                    elif isinstance(df[ref_col], pd.DataFrame):
                        print(f"Column {ref_col} is duplicated in DataFrame. Appending data for each duplicate.")
                        for _, series in df[ref_col].items():
                            merged_data[ref_col].extend(series.tolist())
                else:
                    print(f"Column {ref_col} not found in DataFrame. Adding NaNs.")
                    merged_data[ref_col].extend([np.nan] * len(df))
    
    max_len = max(len(v) for v in merged_data.values())
    for key in merged_data:
        col_len = len(merged_data[key])
        if col_len < max_len:
            merged_data[key].extend([np.nan] * (max_len - col_len))

    merged_df = pd.DataFrame.from_dict(merged_data)
    return merged_df

# %%
# Usage with dataframes and mappings
dfs = [df_2012, df_2013, df_2014]
mappings = [mapping_2012, mapping_2013, mapping_2014]

merged_df = standardize_and_merge(dfs, mappings, all_columns)
# Out:
# Processing DataFrame with columns: ['Unnamed: 0', 'hid', 'round', 'r_pid', 's8p2_q2', 'CA_DOB_d', 'CA_DOB_w', 'CA_DOB_m', 'CA_DOB_y', 's8p2_q4', 's8p3a_q5', 'P_ID', 'D_ID', 'T_ID', 'UC_ID', 'M_ID', 'ICYF_BreastFeed_NoTy', 'ICYF_MFoY_NoTy', 's8p3b_q2', 'ICYF_BreastMilk', 'IYCS_BabyForm', 'IYCS_Water', 'IYCS_MilkPF', 'IYCS_FruitJuice', 'ICYF_PFJ', 'IYCS_WBL', 'ICYF_BabyBottle_1d', 's8p3b_q3', 's8p3b_q4', 's8p3b_q5', 's8p3b_q6', 's8p3b_q7', 's8p3b_q8', 's8p3b_q9', 's8p3b_q10', 's8p3b_q11', 'ICYF_AllMeats', 's8p3b_q16', 's8p3b_q17', 's8p3b_q18', 's8p3b_q19', 's8p3b_q20', 's8p3b_q21', 's8p3b_q22', 's8p3b_q23', 'ICYF_IronTab', 'ICYF_OVoMS_6m', 'ICYF_VoMS_1m', 'ICYF_VS_Name', 'ICYF_SeeEmptyBot', 'ICYF_CVoMS1_1w', 'ICYF_CVoMS2_1w', 'ICYF_CVoMS3_1w', 'ICYF_CVoMS4_1w', 'ICYF_CVoMS5_1w', 'ICYF_CVoMS6_1w', 'ICYF_CVoMS7_1w', 'ICYF_CVoMS8_1w', 'ICYF_CVoMS9_1w', 's8p3a_q2', 's8p3a_q3', 'IYCF_Honey_3d', 'IYCF_Sugar_3d', 'IYCF_Glucose_3d', 'IYCF_Tea_3d', 'IYCF_CowMilk_3d', 'IYCF_BreastMilk_3d', 'IYCF
# ...

# %%
# Rename columns for the merged file (if needed)
rename_mapping = {
   'hid': 'HID',
    'round': 'Survey_Round',
    'r_pid': 'PID',
    's8p2_q2': 'PID_Mom',
    's8p2_q3': 'CA_Age_m',
    's8p2_q4': 'CA_ConfirmBC',
    's8p2_q5_wieght': 'CA_W',
    's8p2_q6_height': 'CA_H',
    's8p2_q7': 'CA_HM',
    's8p3a_q2': 'IYCS_BFFT_hrs',
    's8p3a_q3': 'IYCS_BFFT_d',
    's8p3a_q4': 'IYCS_Colostrum',
    's8p3a_q5': 'IYCS_CStillBF',
    's8p3a_q6': 'IYCS_StopBF_m',
    's8p3a_q7': 'IYCS_MStopBF',
    's8p3a_q8': 'IYCS_CSupp',
    's8p3a_q9': 'IYCS_SafeLiqYN',
    's8p3a_q10': 'IYCS_SafeLiq1',
    's8p3a_q11': 'IYCS_Iron',
    's8p3a_q12': 'IYCS_Vit',
    's8p3b_q2': 'IYCS_SSF_NoT',
    's8p3b_q3': 'IYCS_Cereal',
    's8p3b_q4': 'IYCS_BCereal',
    's8p3b_q5': 'IYCS_Legume',
    's8p3b_q6': 'IYCS_GLVeg',
    's8p3b_q7': 'IYCS_VitARich',
    's8p3b_q8': 'IYCS_OVeg',
    's8p3b_q9': 'IYCS_RBPM',
    's8p3b_q10': 'IYCS_Citrus',
    's8p3b_q11': 'IYCS_OFruits',
    's8p3b_q12': 'IYCS_Meat',
    's8p3b_q13': 'IYCS_Poultry',
    's8p3b_q14': 'IYCS_Seasfood',
    's8p3b_q15': 'IYCS_OrganMeat',
    's8p3b_q16': 'IYCS_Eggs',
    's8p3b_q17': 'IYCS_Nuts',
    's8p3b_q18': 'IYCS_MilkNH',
    's8p3b_q19': 'IYCS_MilkProd',
    's8p3b_q20': 'IYCS_Fats',
    's8p3b_q21': 'IYCS_Chips',
    's8p3b_q22': 'IYCS_BBB',
    's8p3b_q23': 'IYCS_Candies'
}

merged_df.rename(columns=rename_mapping, inplace=True)
'''
# Drop redundant columns
merged_df.drop(merged_df.columns[merged_df.columns.str.contains('Unnamed', case=True)], axis=1, inplace=True)
merged_df.drop(merged_df.columns[merged_df.columns.str.contains(' ', case=False)], axis=1, inplace=True)
'''
# Save the merged dataframe to a CSV file
merged_df.to_csv('1. merged_HnN_Child Anthropometry & IYCF.csv', index=False)
