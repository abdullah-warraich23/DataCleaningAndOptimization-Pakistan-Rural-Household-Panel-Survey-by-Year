# %%
# This code block stores file paths to variables to make the code neat
# The stored variables are called in the read_excel function and stored as dataframes

import pandas as pd
import numpy as np

# Store excel file locations to variables (change it as per your path to file)
file_2012=r"C:\Users\warra\Desktop\Freelance\data\data\FemaleMerge\1. Merging by Parts\6. Section 2 Part 3 Paid farm work during Rabi & Kharif\2012_s2p3a&b_f.csv"
file_2013=r"C:\Users\warra\Desktop\Freelance\data\data\FemaleMerge\1. Merging by Parts\6. Section 2 Part 3 Paid farm work during Rabi & Kharif\2013_s2p3.csv"
file_2014=r"C:\Users\warra\Desktop\Freelance\data\data\FemaleMerge\1. Merging by Parts\6. Section 2 Part 3 Paid farm work during Rabi & Kharif\2014_s2p3.csv"

# Read excel files
df_2012 = pd.read_csv(file_2012)
df_2013 = pd.read_csv(file_2013)
df_2014 = pd.read_csv(file_2014)

# %%
'''
This code block will be used to standardize column names across the years to avoid discrepancies during the merging process.
For example in the roaster data for 2013 rq21 and rq23 are not the same as rq21 and rq23 in 2014 data, but they have the same variable names. Hence, we decide to rename such columns beforehand
We will add the updated name to the mapping dictionaries instead of the original names.

'''

# Rename columns in df_2012
df_2012.rename(columns={
    'S2P3AQ0': 's2p3a_qa',
    'pid': 'r_pid',
    'S2P3AQ1A': 's2p3a_q2',
    'S2P3AQ1B': 's2p3a_q3',
    'S2P3AQ1C': 's2p3a_q4',
    'S2P3AQ2A': 's2p3a_q5',
    'S2P3AQ2B': 's2p3a_q6',
    'S2P3AQ2C': 's2p3a_q7',
    'S2P3AQ3A': 's2p3a_q8',
    'S2P3AQ3B': 's2p3a_q9',
    'S2P3AQ3C': 's2p3a_q10',
    'S2P3AQ4A': 's2p3a_q11',
    'S2P3AQ4B': 's2p3a_q12',
    'S2P3AQ4C': 's2p3a_q13',
    'S2P3AQ5A': 's2p3a_q14',
    'S2P3AQ5B': 's2p3a_q15',
    'S2P3AQ5C': 's2p3a_q16',
    'S2P3BQ1A': 's2p3b_q2',
    'S2P3BQ1B': 's2p3b_q3',
    'S2P3BQ1C': 's2p3b_q4',
    'S2P3BQ2A': 's2p3b_q5',
    'S2P3BQ2B': 's2p3b_q6',
    'S2P3BQ2C': 's2p3b_q7',
    'S2P3BQ3A': 's2p3b_q8',
    'S2P3BQ3B': 's2p3b_q9',
    'S2P3BQ3C': 's2p3b_q10',
    'S2P3BQ4A': 's2p3b_q11',
    'S2P3BQ4B': 's2p3b_q12',
    'S2P3BQ4C': 's2p3b_q13',
    'S2P3BQ5A': 's2p3b_q14',
    'S2P3BQ5B': 's2p3b_q15',
    'S2P3BQ5C': 's2p3b_q16',
    'S2P3BQ0': 's2p3b_qa',
    'S2P3AQ6': 'R_PFWFarmLoc',
    'S2P3AQ7': 'R_PFWDistH',
    'S2P3BQ6': 'K_PFWFarmLoc',
    'S2P3BQ7': 'K_PFWDistH',
    'PROVINCE_ID': 'P_ID',
    'DISTRICT_ID': 'D_ID',
    'TEHSIL_ID': 'T_ID',
    'UC_ID': 'UC_ID',
    'MAUZA_ID': 'M_ID'
}, inplace=True)

# Rename columns in df_2013
df_2013.rename(columns={
    's2p3a_q1a': 's2p3a_q2',
    's2p3a_q1b': 's2p3a_q3',
    's2p3a_q1c': 's2p3a_q4',
    's2p3a_q2a': 's2p3a_q5',
    's2p3a_q2b': 's2p3a_q6',
    's2p3a_q2c': 's2p3a_q7',
    's2p3a_q3a': 's2p3a_q8',
    's2p3a_q3b': 's2p3a_q9',
    's2p3a_q3c': 's2p3a_q10',
    's2p3a_q4a': 's2p3a_q11',
    's2p3a_q4b': 's2p3a_q12',
    's2p3a_q4c': 's2p3a_q13',
    's2p3a_q5a': 's2p3a_q14',
    's2p3a_q5b': 's2p3a_q15',
    's2p3a_q5c': 's2p3a_q16',
    's2p3b_q1a': 's2p3b_q2',
    's2p3b_q1b': 's2p3b_q3',
    's2p3b_q1c': 's2p3b_q4',
    's2p3b_q2a': 's2p3b_q5',
    's2p3b_q2b': 's2p3b_q6',
    's2p3b_q2c': 's2p3b_q7',
    's2p3b_q3a': 's2p3b_q8',
    's2p3b_q3b': 's2p3b_q9',
    's2p3b_q3c': 's2p3b_q10',
    's2p3b_q4a': 's2p3b_q11',
    's2p3b_q4b': 's2p3b_q12',
    's2p3b_q4c': 's2p3b_q13',
    's2p3b_q5a': 's2p3b_q14',
    's2p3b_q5b': 's2p3b_q15',
    's2p3b_q5c': 's2p3b_q16'
}, inplace=True)

# df_2014 doesn't need renaming as it is the reference

# %%
# Updated mappings

mapping_2012 = [
    'hid', 'round', 's2p3a_qa', 'r_pid', None, 's2p3a_q2', 's2p3a_q3', 's2p3a_q4',
    's2p3a_q5', 's2p3a_q6', 's2p3a_q7', 's2p3a_q8', 's2p3a_q9', 's2p3a_q10', 's2p3a_q11',
    's2p3a_q12', 's2p3a_q13', 's2p3a_q14', 's2p3a_q15', 's2p3a_q16', None, None, None,
    's2p3b_q2', 's2p3b_q3', 's2p3b_q4', 's2p3b_q5', 's2p3b_q6', 's2p3b_q7', 's2p3b_q8',
    's2p3b_q9', 's2p3b_q10', 's2p3b_q11', 's2p3b_q12', 's2p3b_q13', 's2p3b_q14', 's2p3b_q15',
    's2p3b_q16', None, None, 's2p3b_qa', 'R_PFWFarmLoc', 'R_PFWDistH', 'K_PFWFarmLoc',
    'K_PFWDistH', 'P_ID', 'D_ID', 'T_ID', 'UC_ID', 'M_ID'
]

mapping_2013 = [
    'hid', 'round', None, 'r_pid', None, 's2p3a_q2', 's2p3a_q3', 's2p3a_q4', 's2p3a_q5', 's2p3a_q6', 's2p3a_q7', 
    's2p3a_q8', 's2p3a_q9', 's2p3a_q10', 's2p3a_q11', 's2p3a_q12', 's2p3a_q13', 's2p3a_q14', 's2p3a_q15', 's2p3a_q16', 
    None, None, None, 's2p3b_q2', 's2p3b_q3', 's2p3b_q4', 's2p3b_q5', 's2p3b_q6', 's2p3b_q7', 's2p3b_q8', 's2p3b_q9', 
    's2p3b_q10', 's2p3b_q11', 's2p3b_q12', 's2p3b_q13', 's2p3b_q14', 's2p3b_q15', 's2p3b_q16', None, None, None, None, 
    None, None, None, None, None, None, None, None
]

mapping_2014 = [
    'hid', 'round', 's2p3a_qa', 'r_pid', 's2p3a_q1', 's2p3a_q2', 's2p3a_q3',
    's2p3a_q4', 's2p3a_q5', 's2p3a_q6', 's2p3a_q7', 's2p3a_q8', 's2p3a_q9',
    's2p3a_q10', 's2p3a_q11', 's2p3a_q12', 's2p3a_q13', 's2p3a_q14', 's2p3a_q15',
    's2p3a_q16', 's2p3a_q17', 's2p3a_q18', 's2p3b_q1', 's2p3b_q2', 's2p3b_q3',
    's2p3b_q4', 's2p3b_q5', 's2p3b_q6', 's2p3b_q7', 's2p3b_q8', 's2p3b_q9',
    's2p3b_q10', 's2p3b_q11', 's2p3b_q12', 's2p3b_q13', 's2p3b_q14', 's2p3b_q15',
    's2p3b_q16', 's2p3b_q17', 's2p3b_q18', 's2p3b_qa', None, None, None, None, None, None, None, None, None
]

# %%
# Create a list of all possible columns in the correct order
all_columns = []

for col in mapping_2012:
    if col and col not in all_columns:
        all_columns.append(col)   
for col in mapping_2013:
    if col and col not in all_columns:
        all_columns.append(col)
for col in mapping_2014:
    if col and col not in all_columns:
        all_columns.append(col)

# %%
def standardize_and_merge(dfs, mappings, all_columns):
    merged_data = {col: [] for col in all_columns}

    for df, mapping in zip(dfs, mappings):
        print(f"Processing DataFrame with columns: {df.columns.tolist()}")
        for i, col in enumerate(mapping):
            if col:
                ref_col = col.strip()  # Remove leading/trailing whitespace
                if ref_col not in merged_data:
                    merged_data[ref_col] = []
                if ref_col in df.columns:
                    print(f"Appending data for column {ref_col}")
                    if isinstance(df[ref_col], pd.Series):
                        merged_data[ref_col].extend(df[ref_col].tolist())
                    elif isinstance(df[ref_col], pd.DataFrame):
                        print(f"Column {ref_col} is duplicated in DataFrame. Appending data for each duplicate.")
                        for _, series in df[ref_col].items():
                            merged_data[ref_col].extend(series.tolist())
                else:
                    print(f"Column {ref_col} not found in DataFrame. Adding NaNs.")
                    merged_data[ref_col].extend([np.nan] * len(df))
    
    max_len = max(len(v) for v in merged_data.values())
    for key in merged_data:
        col_len = len(merged_data[key])
        if col_len < max_len:
            merged_data[key].extend([np.nan] * (max_len - col_len))

    merged_df = pd.DataFrame.from_dict(merged_data)
    return merged_df

# %%
# Usage with dataframes and mappings
dfs = [df_2012, df_2013, df_2014]
mappings = [mapping_2012, mapping_2013, mapping_2014]

merged_df = standardize_and_merge(dfs, mappings, all_columns)
# Out:
# Processing DataFrame with columns: ['Unnamed: 0.1', 'Unnamed: 0', 'hid', 'round', 'r_pid', 's2p3a_qa', 's2p3a_q2', 's2p3a_q3', 's2p3a_q4', 's2p3a_q5', 's2p3a_q6', 's2p3a_q7', 's2p3a_q8', 's2p3a_q9', 's2p3a_q10', 's2p3a_q11', 's2p3a_q12', 's2p3a_q13', 's2p3a_q14', 's2p3a_q15', 's2p3a_q16', 'R_PFWFarmLoc', 'R_PFWDistH', 's2p3b_qa', 's2p3b_q2', 's2p3b_q3', 's2p3b_q4', 's2p3b_q5', 's2p3b_q6', 's2p3b_q7', 's2p3b_q8', 's2p3b_q9', 's2p3b_q10', 's2p3b_q11', 's2p3b_q12', 's2p3b_q13', 's2p3b_q14', 's2p3b_q15', 's2p3b_q16', 'K_PFWFarmLoc', 'K_PFWDistH', 'P_ID', 'D_ID', 'T_ID', 'UC_ID', 'M_ID']
# Appending data for column hid
# Appending data for column round
# Appending data for column s2p3a_qa
# Appending data for column r_pid
# Appending data for column s2p3a_q2
# Appending data for column s2p3a_q3
# Appending data for column s2p3a_q4
# Appending data for column s2p3a_q5
# Appending data for column s2p3a_q6
# Appending data for column s2p3a_q7
# Appending data for column s2p3a_q8
# ...

# %%
# Rename columns for the merged file (if needed)
rename_mapping = {
    'hid': 'HID',
    'round': 'Survey_Round',
    's2p3a_qa': 'R_PFW',
    'r_pid': 'PID',
    's2p3a_q1': 'R_PFWEmpStatus',
    's2p3a_q2': 'R_PFWSowing_HpD',
    's2p3a_q3': 'R_PFWSowing_TD',
    's2p3a_q4': 'R_PFWSowing_TWpD',
    's2p3a_q5': 'R_PFWWeeding_HpD',
    's2p3a_q6': 'R_PFWWeeding_TD',
    's2p3a_q7': 'R_PFWWeeding_WpD',
    's2p3a_q8': 'R_PFWHar_HpD',
    's2p3a_q9': 'R_PFWHar_TD',
    's2p3a_q10': 'R_PFWHar_WpD',
    's2p3a_q11': 'R_PFWPHA_HpD',
    's2p3a_q12': 'R_PFWPHA_TD',
    's2p3a_q13': 'R_PFWPHA_WpD',
    's2p3a_q14': 'R_PFWOA_HpD',
    's2p3a_q15': 'R_PFWOA_TD',
    's2p3a_q16': 'R_PFWOA_WpD',
    's2p3a_q17': 'R_PFWTI_TD',
    's2p3a_q18': 'R_PFWTI_TWpA',
    's2p3b_q1': 'K_PFWEmpStatus',
    's2p3b_q2': 'K_PFWSowing_HpD',
    's2p3b_q3': 'K_PFWSowing_TD',
    's2p3b_q4': 'K_PFWSowing_TWpD',
    's2p3b_q5': 'K_PFWWeeding_HpD',
    's2p3b_q6': 'K_PFWWeeding_TD',
    's2p3b_q7': 'K_PFWWeeding_WpD',
    's2p3b_q8': 'K_PFWHar_HpD',
    's2p3b_q9': 'K_PFWHar_TD',
    's2p3b_q10': 'K_PFWHar_WpD',
    's2p3b_q11': 'K_PFWPHA_HpD',
    's2p3b_q12': 'K_PFWPHA_TD',
    's2p3b_q13': 'K_PFWPHA_WpD',
    's2p3b_q14': 'K_PFWOA_HpD',
    's2p3b_q15': 'K_PFWOA_TD',
    's2p3b_q16': 'K_PFWOA_WpD',
    's2p3b_q17': 'K_PFWTI_TD',
    's2p3b_q18': 'K_PFWTI_TWpA',
    's2p3b_qa': 'K_PFW'
}

merged_df.rename(columns=rename_mapping, inplace=True)
'''
# Drop redundant columns
merged_df.drop(merged_df.columns[merged_df.columns.str.contains('Unnamed', case=True)], axis=1, inplace=True)
merged_df.drop(merged_df.columns[merged_df.columns.str.contains(' ', case=False)], axis=1, inplace=True)
'''
# Save the merged dataframe to a CSV file
merged_df.to_csv('4. merged_EnI_Paid Farm Work During R&K.csv', index=False)
