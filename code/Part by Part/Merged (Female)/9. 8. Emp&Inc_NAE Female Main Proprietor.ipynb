# %%
# This code block stores file paths to variables to make the code neat
# The stored variables are called in the read_excel function and stored as dataframes

import pandas as pd
import numpy as np

# Store excel file locations to variables (change it as per your path to file)
file_2012=r"C:\Users\warra\Desktop\Freelance\data\data\FemaleMerge\1. Merging by Parts\9. Section 2 Part 5a Non-Agricultural Enterprises during last 12 months Female main proprietor\2012_hh_business.csv"
file_2013=r"C:\Users\warra\Desktop\Freelance\data\data\FemaleMerge\1. Merging by Parts\9. Section 2 Part 5a Non-Agricultural Enterprises during last 12 months Female main proprietor\2013_s2p5a_f.csv"
file_2014=r"C:\Users\warra\Desktop\Freelance\data\data\FemaleMerge\1. Merging by Parts\9. Section 2 Part 5a Non-Agricultural Enterprises during last 12 months Female main proprietor\2014_s2p5a_f.csv"

# Read excel files
df_2012 = pd.read_csv(file_2012)
df_2013 = pd.read_csv(file_2013)
df_2014 = pd.read_csv(file_2014)

# %%
'''
This code block will be used to standardize column names across the years to avoid discrepancies during the merging process.
For example in the roaster data for 2013 rq21 and rq23 are not the same as rq21 and rq23 in 2014 data, but they have the same variable names. Hence, we decide to rename such columns beforehand
We will add the updated name to the mapping dictionaries instead of the original names.

'''

# Rename columns in df_2012
df_2012.rename(columns={
    'business_no': 'business_id',
    'pid': 'r_pid',
    'part1q4': 's2p5a_q3',
    'part1q5': 's2p5a_q4',
    'part1q6': 's2p5a_q6',
    'part1q7': 's2p5a_q7',
    'part1q8a': 's2p5a_q13',
    'part1q8b': 's2p5a_q14',
    'part1q9a': 's2p5a_q15',
    'part1q9b': 's2p5a_q16',
    'part1q10a': 's2p5a_q17',
    'part1q10b': 's2p5a_q18',
    'part1q10c': 's2p5a_q19',
    'part1q11a': 's2p5a_q20',
    'part1q11b': 's2p5a_q21',
    'part1q11c': 's2p5a_q22',
    'part1q12': 's2p5a_q23',
    'part1q13': 's2p5a_q24',
    'part1q14': 's2p5a_q25',
    'part1q15': 's2p5a_q26'
}, inplace=True)

# Rename columns in df_2013
df_2013.rename(columns={
    's2p5a_q5': 's2p5a_q6',
    's2p5a_q6': 's2p5a_q7',
    's2p5a_q7': 's2p5a_q8',
    's2p5a_q8': 's2p5a_q9',
    's2p5a_q9': 's2p5a_q10',
    's2p5a_q10a': 's2p5a_q13',
    's2p5a_q10b': 's2p5a_q14',
    's2p5a_q11a': 's2p5a_q15',
    's2p5a_q11b': 's2p5a_q16',
    's2p5a_q12a': 's2p5a_q17',
    's2p5a_q12b': 's2p5a_q18',
    's2p5a_q12c': 's2p5a_q19',
    's2p5a_q13a': 's2p5a_q20',
    's2p5a_q13b': 's2p5a_q21',
    's2p5a_q13c': 's2p5a_q22',
    's2p5a_q14': 's2p5a_q23',
    's2p5a_q15': 's2p5a_q24',
    's2p5a_q16': 's2p5a_q25',
    's2p5a_q17': 's2p5a_q26'
}, inplace=True)

# df_2014 doesn't need renaming as it is the reference

# %%
# Updated mappings

mapping_2012 = [
    'hid', 'round', None, 'business_id', 'r_pid', 's2p5a_q3', 's2p5a_q4', None, 's2p5a_q6', 's2p5a_q7',
    None, None, None, None, None, 's2p5a_q13', 's2p5a_q14', 's2p5a_q15', 's2p5a_q16', 's2p5a_q17',
    's2p5a_q18', 's2p5a_q19', 's2p5a_q20', 's2p5a_q21', 's2p5a_q22', 's2p5a_q23', 's2p5a_q24', 's2p5a_q25', 's2p5a_q26'
]

mapping_2013 = [
    'hid', 'round', None, 'business_id', 'r_pid', 's2p5a_q3', 's2p5a_q4', None, 's2p5a_q6', 's2p5a_q7', 
    's2p5a_q8', 's2p5a_q9', 's2p5a_q10', None, None, 's2p5a_q13', 's2p5a_q14', 's2p5a_q15', 's2p5a_q16', 's2p5a_q17', 
    's2p5a_q18', 's2p5a_q19', 's2p5a_q20', 's2p5a_q21', 's2p5a_q22', 's2p5a_q23', 's2p5a_q24', 's2p5a_q25', 
    's2p5a_q26'
]


mapping_2014 = [
    'hid', 'round', 's2p5a_qa', 'business_id', 'r_pid', 's2p5a_q3', 's2p5a_q4', 's2p5a_q5',
    's2p5a_q6', 's2p5a_q7', 's2p5a_q8', 's2p5a_q9', 's2p5a_q10', 's2p5a_q11', 's2p5a_q12',
    's2p5a_q13', 's2p5a_q14', 's2p5a_q15', 's2p5a_q16', 's2p5a_q17', 's2p5a_q18', 's2p5a_q19',
    's2p5a_q20', 's2p5a_q21', 's2p5a_q22', 's2p5a_q23', 's2p5a_q24', 's2p5a_q25', 's2p5a_q26'
]

# %%
# Create a list of all possible columns in the correct order
all_columns = []

for col in mapping_2012:
    if col and col not in all_columns:
        all_columns.append(col)   
for col in mapping_2013:
    if col and col not in all_columns:
        all_columns.append(col)
for col in mapping_2014:
    if col and col not in all_columns:
        all_columns.append(col)

# %%
def standardize_and_merge(dfs, mappings, all_columns):
    merged_data = {col: [] for col in all_columns}

    for df, mapping in zip(dfs, mappings):
        print(f"Processing DataFrame with columns: {df.columns.tolist()}")
        for i, col in enumerate(mapping):
            if col:
                ref_col = col.strip()  # Remove leading/trailing whitespace
                if ref_col not in merged_data:
                    merged_data[ref_col] = []
                if ref_col in df.columns:
                    print(f"Appending data for column {ref_col}")
                    if isinstance(df[ref_col], pd.Series):
                        merged_data[ref_col].extend(df[ref_col].tolist())
                    elif isinstance(df[ref_col], pd.DataFrame):
                        print(f"Column {ref_col} is duplicated in DataFrame. Appending data for each duplicate.")
                        for _, series in df[ref_col].items():
                            merged_data[ref_col].extend(series.tolist())
                else:
                    print(f"Column {ref_col} not found in DataFrame. Adding NaNs.")
                    merged_data[ref_col].extend([np.nan] * len(df))
    
    max_len = max(len(v) for v in merged_data.values())
    for key in merged_data:
        col_len = len(merged_data[key])
        if col_len < max_len:
            merged_data[key].extend([np.nan] * (max_len - col_len))

    merged_df = pd.DataFrame.from_dict(merged_data)
    return merged_df

# %%
# Usage with dataframes and mappings
dfs = [df_2012, df_2013, df_2014]
mappings = [mapping_2012, mapping_2013, mapping_2014]

merged_df = standardize_and_merge(dfs, mappings, all_columns)
# Out:
# Processing DataFrame with columns: ['Unnamed: 0.1', 'Unnamed: 0', 'hid', 'round', 'business_id', 'r_pid', 's2p5a_q3', 's2p5a_q4', 's2p5a_q6', 's2p5a_q7', 's2p5a_q13', 's2p5a_q14', 's2p5a_q15', 's2p5a_q16', 's2p5a_q17', 's2p5a_q18', 's2p5a_q19', 's2p5a_q20', 's2p5a_q21', 's2p5a_q22', 's2p5a_q23', 's2p5a_q24', 's2p5a_q25', 's2p5a_q26']
# Appending data for column hid
# Appending data for column round
# Appending data for column business_id
# Appending data for column r_pid
# Appending data for column s2p5a_q3
# Appending data for column s2p5a_q4
# Appending data for column s2p5a_q6
# Appending data for column s2p5a_q7
# Appending data for column s2p5a_q13
# Appending data for column s2p5a_q14
# Appending data for column s2p5a_q15
# Appending data for column s2p5a_q16
# Appending data for column s2p5a_q17
# Appending data for column s2p5a_q18
# Appending data for column s2p5a_q19
# Appending data for column s2p5a_q20
# Appending data for column s2p5a_q21
# Appending data for column s2p5a_q22
# Appending data for column s2p5a_q23
# Appending data for column s2p5a_q24
# Appending data for column s2p5a_q25
# Appending data for column s2p5a_q26
# Processing DataFrame with columns: ['Unnamed: 0', 'hid', 'round', 'business_id', 'r_pid', 's2p5a_q3', 's2p5a_q4', 's2p5a_q6', 's2p5a_q7', 's2p5a_q8', 's2p5a_q9', 's2p5a_q10', 's2p5a_q13', 's2p5a_q14', 's2p5a_q15', 's2p5a_q16', 's2p5a_q17', 's2p5a_q18', 's2p5a_q19', 's2p5a_q20', 's2p5a_q21', 's2p5a_q22', 's2p5a_q23', 's2p5a_q24', 's2p5a_q25', 's2p5a_q26']
# Appending data for column hid
# Appending data for column round
# Appending data for column business_id
# Appending data for column r_pid
# Appending data for column s2p5a_q3
# Appending data for column s2p5a_q4
# Appending data for column s2p5a_q6
# Appending data for column s2p5a_q7
# Appending data for column s2p5a_q8
# Appending data for column s2p5a_q9
# Appending data for column s2p5a_q10
# Appending data for column s2p5a_q13
# Appending data for column s2p5a_q14
# Appending data for column s2p5a_q15
# Appending data for column s2p5a_q16
# Appending data for column s2p5a_q17
# Appending data for column s2p5a_q18
# Appending data for column s2p5a_q19
# Appending data for column s2p5a_q20
# Appending data for column s2p5a_q21
# Appending data for column s2p5a_q22
# Appending data for column s2p5a_q23
# Appending data for column s2p5a_q24
# Appending data for column s2p5a_q25
# Appending data for column s2p5a_q26
# Processing DataFrame with columns: ['Unnamed: 0', 'hid', 'round', 's2p5a_qa', 'business_id', 'r_pid', 's2p5a_q3', 's2p5a_q4', 's2p5a_q5', 's2p5a_q6', 's2p5a_q7', 's2p5a_q8', 's2p5a_q9', 's2p5a_q10', 's2p5a_q11', 's2p5a_q12', 's2p5a_q13', 's2p5a_q14', 's2p5a_q15', 's2p5a_q16', 's2p5a_q17', 's2p5a_q18', 's2p5a_q19', 's2p5a_q20', 's2p5a_q21', 's2p5a_q22', 's2p5a_q23', 's2p5a_q24', 's2p5a_q25', 's2p5a_q26']
# Appending data for column hid
# Appending data for column round
# Appending data for column s2p5a_qa
# Appending data for column business_id
# Appending data for column r_pid
# Appending data for column s2p5a_q3
# Appending data for column s2p5a_q4
# Appending data for column s2p5a_q5
# Appending data for column s2p5a_q6
# Appending data for column s2p5a_q7
# Appending data for column s2p5a_q8
# Appending data for column s2p5a_q9
# Appending data for column s2p5a_q10
# Appending data for column s2p5a_q11
# Appending data for column s2p5a_q12
# Appending data for column s2p5a_q13
# Appending data for column s2p5a_q14
# Appending data for column s2p5a_q15
# Appending data for column s2p5a_q16
# Appending data for column s2p5a_q17
# Appending data for column s2p5a_q18
# Appending data for column s2p5a_q19
# Appending data for column s2p5a_q20
# Appending data for column s2p5a_q21
# Appending data for column s2p5a_q22
# Appending data for column s2p5a_q23
# Appending data for column s2p5a_q24
# Appending data for column s2p5a_q25
# Appending data for column s2p5a_q26

# %%
# Rename columns for the merged file (if needed)
rename_mapping = {
    'hid': 'HID',
    'round': 'Survey_Round',
    's2p5a_qa': 'NAE_YN',
    'business_id': 'NAE_BID',
    'r_pid': 'PID',
    's2p5a_q3': 'NAE_Otype',
    's2p5a_q4': 'NAE_BReg',
    's2p5a_q5': 'NAE_NoBReg_Res',
    's2p5a_q6': 'NAE_E_IoO',
    's2p5a_q7': 'NAE_E_ST',
    's2p5a_q8': 'NAE_SC_S1',
    's2p5a_q9': 'NAE_SC_S2',
    's2p5a_q10': 'NAE_Einit_Val',
    's2p5a_q11': 'NAE_BDS_Acc',
    's2p5a_q12': 'NAE_BDS_Name',
    's2p5a_q13': 'NAE_SEP_NoPTotal',
    's2p5a_q14': 'NAE_SEP_PD',
    's2p5a_q15': 'NAE_UFL_NoP',
    's2p5a_q16': 'NAE_UFL_PD',
    's2p5a_q17': 'NAE_PHL_NoP',
    's2p5a_q18': 'NAE_PHL_PD',
    's2p5a_q19': 'NAE_PHL_AL',
    's2p5a_q20': 'NAE_CHL_NoP',
    's2p5a_q21': 'NAE_CHL_PD',
    's2p5a_q22': 'NAE_CHL_AL',
    's2p5a_q23': 'NAE_Loc',
    's2p5a_q24': 'NAE_PS',
    's2p5a_q25': 'NAE_LocPS',
    's2p5a_q26': 'NAE_OpT'
}

merged_df.rename(columns=rename_mapping, inplace=True)
'''
# Drop redundant columns
merged_df.drop(merged_df.columns[merged_df.columns.str.contains('Unnamed', case=True)], axis=1, inplace=True)
merged_df.drop(merged_df.columns[merged_df.columns.str.contains(' ', case=False)], axis=1, inplace=True)
'''
# Save the merged dataframe to a CSV file
merged_df.to_csv('7. merged_merged_EnI_NAE Female Main Proprietor.csv', index=False)
